# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
introdu_doc = nlp("""N early ten years had passed since the Dursleys had woken up to find their
nephew on the front step, but Privet Drive had hardly changed at all. The sun
rose on the same tidy front gardens and lit up the brass number four on the
Dursleys’ front door; it crept into their living room, which was almost exactly
the same as it had been on the night when Mr. Dursley had seen that fateful news
report about the owls. Only the photographs on the mantelpiece really showed
how much time had passed. Ten years ago, there had been lots of pictures of
what looked like a large pink beach ball wearing different-colored bonnets —
but Dudley Dursley was no longer a baby, and now the photographs showed a
large blond boy riding his first bicycle, on a carousel at the fair, playing a
computer game with his father, being hugged and kissed by his mother. The
room held no sign at all that another boy lived in the house, too.
Yet Harry Potter was still there, asleep at the moment, but not for long.
His Aunt Petunia was awake and it was her shrill voice that made the first noise
of the day.""")

# %%
[token.text for token in introdu_doc][:10]
# Out:
# ['N',
#  'early',
#  'ten',
#  'years',
#  'had',
#  'passed',
#  'since',
#  'the',
#  'Dursleys',
#  'had']

# %%
import pathlib
docs = nlp(pathlib.Path("./example.txt").read_text(encoding="utf-8"))
print([token.text for token in docs][:10])
# Out:
# ['THE', 'VANISHING', 'GLASS', '\n', 'N', 'early', 'ten', 'years', 'had', 'passed']

# %% [markdown]
# Sentence DEtection

# %%
sentences  = list(introdu_doc.sents)
sentences[:10]
# Out:
# [N early ten years had passed since the Dursleys had woken up to find their
#  nephew on the front step, but Privet Drive had hardly changed at all.,
#  The sun
#  rose on the same tidy front gardens and lit up the brass number four on the
#  Dursleys’ front door; it crept into their living room, which was almost exactly
#  the same as it had been on the night when Mr. Dursley had seen that fateful news
#  report about the owls.,
#  Only the photographs on the mantelpiece really showed
#  how much time had passed.,
#  Ten years ago, there had been lots of pictures of
#  what looked like a large pink beach ball wearing different-colored bonnets —
#  but Dudley Dursley was no longer a baby, and now the photographs showed a
#  large blond boy riding his first bicycle, on a carousel at the fair, playing a
#  computer game with his father, being hugged and kissed by his mother.,
#  The
#  room held no sign at all that another boy lived in the house, too.,
#  Yet Harry Potter was still there, asleep at the moment, but not for long.,
#  His Aunt Petunia was awake and it was her shrill voice that made the first noise
#  of the day.]

# %% [markdown]
# Creating a custom seperator

# %%
from spacy.language import Language

ellipsis_text =  """Gus, can you, ... never mind, I forgot
    what I was saying. So, do you think
    we should...
"""

@Language.component("custm_sep")
def custm(doc):
    tokens = list(doc)
    for token in tokens[::-1]:
        if token.text == "...":
            doc[token.i + 1].is_sent_start = True
    return doc

custm_nlp = spacy.load("en_core_web_sm")
custm_nlp.add_pipe("custm_sep", before="parser")

custm_nlp_doc = custm_nlp(ellipsis_text)


custm_nlp_sents = list(custm_nlp_doc.sents)

print(custm_nlp_sents)
# Out:
# [Gus, can you, ..., never mind, I forgot
#     what I was saying., So, do you think
#     we should...,
# ]

# %% [markdown]
# Tokens

# %%
tokens = list(docs)
for token in tokens[:10]:
    print(token, token.idx)
# Out:
# THE 0
# VANISHING 4
# GLASS 14
#
#  19
# N 20
# early 22
# ten 28
# years 32
# had 38
# passed 42

# %% [markdown]
# About tokens

# %%
for token in tokens:
    print(f"{token} => {token.text_with_ws} , {token.is_alpha}, {token.is_punct}, {token.is_stop}")
# Out:
# THE => THE  , True, False, True
# VANISHING => VANISHING  , True, False, False
# GLASS => GLASS , True, False, False
#
#  =>
#  , False, False, False
# N => N  , True, False, False
# early => early  , True, False, False
# ten => ten  , True, False, True
# years => years  , True, False, False
# had => had  , True, False, True
# passed => passed  , True, False, False
# since => since  , True, False, True
# the => the  , True, False, True
# Dursleys => Dursleys  , True, False, False
# had => had  , True, False, True
# woken => woken  , True, False, False
# up => up  , True, False, True
# to => to  , True, False, True
# find => find  , True, False, False
# their => their , True, False, True
#
#  =>
#  , False, False, False
# nephew => nephew  , True, False, False
# on => on  , True, False, True
# the => the  , True, False, True
# front => front  , True, False, True
# step => step , True, False, False
# , => ,  , False, True, False
# but => but  , True, False, True
# Privet => Privet  , True, False, False
# Drive => Drive  , True, False, False
# had => had  , True, False, True
# hardly => hardly  , True, False, False
# changed => changed  , True, False, False
# at => at  , True, False, True
# all => all , True, False, True
# . => .  , False, True, False
# The => The  , True, False, True
# sun => sun , True, False, False
#
#  =>
#  , False, False, False
# rose => rose  , True, False, False
# on => on  , True, False, True
# the => the  , True, False, True
# same => same  , True, False, True
# tidy => tidy  , True, False, False
# front => front  , True, False, True
# gardens => gardens  , True, False, False
# and => and  , True, False, True
# lit => lit  , True, False, False
# up => up  , True, False, True
# the => the  , True, False, True
# brass => brass  , True, False, False
# number => number  , True, False, False
# four => four  , True, False, True
# on => on  , True, False, True
# the => the , True, False, True
#
#  =>
#  , False, False, False
# Dursleys => Dursleys , True, False, False
# ’ => ’  , False, True, False
# front => front  , True, False, True
# door => door , True, False, False
# ; => ;  , False, True, False
# it => it  , True, False, True
# crept => crept  , True, False, False
# into => into  , True, False, True
# their => their  , True, False, True
# living => living  , True, False, False
# room => room , True, False, False
# , => ,  , False, True, False
# which => which  , True, False, True
# was => was  , True, False, True
# almost => almost  , True, False, True
# exactly => exactly , True, False, False
#
#  =>
#  , False, False, False
# the => the  , True, False, True
# same => same  , True, False, True
# as => as  , True, False, True
# it => it  , True, False, True
# had => had  , True, False, True
# been => been  , True, False, True
# on => on  , True, False, True
# the => the  , True, False, True
# night => night  , True, False, False
# when => when  , True, False, True
# Mr. => Mr.  , False, False, False
# Dursley => Dursley  , True, False, False
# had => had  , True, False, True
# seen => seen  , True, False, False
# that => that  , True, False, True
# fateful => fateful  , True, False, False
# news => news , True, False, False
#
#  =>
#  , False, False, False
# report => report  , True, False, False
# about => about  , True, False, True
# the => the  , True, False, True
# owls => owls , True, False, False
# . => .  , False, True, False
# Only => Only  , True, False, True
# the => the  , True, False, True
# photographs => photographs  , True, False, False
# on => on  , True, False, True
# the => the  , True, False, True
# mantelpiece => mantelpiece  , True, False, False
# really => really  , True, False, True
# showed => showed , True, False, False
#
#  =>
#  , False, False, False
# how => how  , True, False, True
# much => much  , True, False, True
# time => time  , True, False, False
# had => had  , True, False, True
# passed => passed , True, False, False
# . => .  , False, True, False
# Ten => Ten  , True, False, True
# years => years  , True, False, False
# ago => ago , True, False, False
# , => ,  , False, True, False
# there => there  , True, False, True
# had => had  , True, False, True
# been => been  , True, False, True
# lots => lots  , True, False, False
# of => of  , True, False, True
# pictures => pictures  , True, False, False
# of => of , True, False, True
#
#  =>
#  , False, False, False
# what => what  , True, False, True
# looked => looked  , True, False, False
# like => like  , True, False, False
# a => a  , True, False, True
# large => large  , True, False, False
# pink => pink  , True, False, False
# beach => beach  , True, False, False
# ball => ball  , True, False, False
# wearing => wearing  , True, False, False
# different => different , True, False, False
# - => - , False, True, False
# colored => colored  , True, False, False
# bonnets => bonnets  , True, False, False
# — => — , False, True, False
#
#  =>
#  , False, False, False
# but => but  , True, False, True
# Dudley => Dudley  , True, False, False
# Dursley => Dursley  , True, False, False
# was => was  , True, False, True
# no => no  , True, False, True
# longer => longer  , True, False, False
# a => a  , True, False, True
# baby => baby , True, False, False
# , => ,  , False, True, False
# and => and  , True, False, True
# now => now  , True, False, True
# the => the  , True, False, True
# photographs => photographs  , True, False, False
# showed => showed  , True, False, False
# a => a , True, False, True
#
#  =>
#  , False, False, False
# large => large  , True, False, False
# blond => blond  , True, False, False
# boy => boy  , True, False, False
# riding => riding  , True, False, False
# his => his  , True, False, True
# first => first  , True, False, True
# bicycle => bicycle , True, False, False
# , => ,  , False, True, False
# on => on  , True, False, True
# a => a  , True, False, True
# carousel => carousel  , True, False, False
# at => at  , True, False, True
# the => the  , True, False, True
# fair => fair , True, False, False
# , => ,  , False, True, False
# playing => playing  , True, False, False
# a => a , True, False, True
#
#  =>
#  , False, False, False
# computer => computer  , True, False, False
# game => game  , True, False, False
# with => with  , True, False, True
# his => his  , True, False, True
# father => father , True, False, False
# , => ,  , False, True, False
# being => being  , True, False, True
# hugged => hugged  , True, False, False
# and => and  , True, False, True
# kissed => kissed  , True, False, False
# by => by  , True, False, True
# his => his  , True, False, True
# mother => mother , True, False, False
# . => .  , False, True, False
# The => The , True, False, True
#
#  =>
#  , False, False, False
# room => room  , True, False, False
# held => held  , True, False, False
# no => no  , True, False, True
# sign => sign  , True, False, False
# at => at  , True, False, True
# all => all  , True, False, True
# that => that  , True, False, True
# another => another  , True, False, True
# boy => boy  , True, False, False
# lived => lived  , True, False, False
# in => in  , True, False, True
# the => the  , True, False, True
# house => house , True, False, False
# , => ,  , False, True, False
# too => too , True, False, True
# . => . , False, True, False
#
#  =>
#  , False, False, False
# Yet => Yet  , True, False, True
# Harry => Harry  , True, False, False
# Potter => Potter  , True, False, False
# was => was  , True, False, True
# still => still  , True, False, True
# there => there , True, False, True
# , => ,  , False, True, False
# asleep => asleep  , True, False, False
# at => at  , True, False, True
# the => the  , True, False, True
# moment => moment , True, False, False
# , => ,  , False, True, False
# but => but  , True, False, True
# not => not  , True, False, True
# for => for  , True, False, True
# long => long , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# His => His  , True, False, True
# Aunt => Aunt  , True, False, False
# Petunia => Petunia  , True, False, False
# was => was  , True, False, True
# awake => awake  , True, False, False
# and => and  , True, False, True
# it => it  , True, False, True
# was => was  , True, False, True
# her => her  , True, False, True
# shrill => shrill  , True, False, False
# voice => voice  , True, False, False
# that => that  , True, False, True
# made => made  , True, False, True
# the => the  , True, False, True
# first => first  , True, False, True
# noise => noise , True, False, False
#
#  =>
#  , False, False, False
# of => of  , True, False, True
# the => the  , True, False, True
# day => day , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# “ => “ , False, True, False
# Up => Up , True, False, True
# ! => !  , False, True, False
# Get => Get  , True, False, True
# up => up , True, False, True
# ! => !  , False, True, False
# Now => Now , True, False, True
# ! => ! , False, True, False
# ” => ” , False, True, False
#
#  =>
#  , False, False, False
# Harry => Harry  , True, False, False
# woke => woke  , True, False, False
# with => with  , True, False, True
# a => a  , True, False, True
# start => start , True, False, False
# . => .  , False, True, False
# His => His  , True, False, True
# aunt => aunt  , True, False, False
# rapped => rapped  , True, False, False
# on => on  , True, False, True
# the => the  , True, False, True
# door => door  , True, False, False
# again => again , True, False, True
# . => . , False, True, False
#
#  =>
#  , False, False, False
# “ => “ , False, True, False
# Up => Up , True, False, True
# ! => ! , False, True, False
# ” => ”  , False, True, False
# she => she  , True, False, True
# screeched => screeched , True, False, False
# . => .  , False, True, False
# Harry => Harry  , True, False, False
# heard => heard  , True, False, False
# her => her  , True, False, True
# walking => walking  , True, False, False
# toward => toward  , True, False, True
# the => the  , True, False, True
# kitchen => kitchen  , True, False, False
# and => and , True, False, True
#
#  =>
#  , False, False, False
# then => then  , True, False, True
# the => the  , True, False, True
# sound => sound  , True, False, False
# of => of  , True, False, True
# the => the  , True, False, True
# frying => frying  , True, False, False
# pan => pan  , True, False, False
# being => being  , True, False, True
# put => put  , True, False, True
# on => on  , True, False, True
# the => the  , True, False, True
# stove => stove , True, False, False
# . => .  , False, True, False
# He => He  , True, False, True
# rolled => rolled  , True, False, False
# onto => onto  , True, False, True
# his => his  , True, False, True
# back => back , True, False, True
#
#  =>
#  , False, False, False
# and => and  , True, False, True
# tried => tried  , True, False, False
# to => to  , True, False, True
# remember => remember  , True, False, False
# the => the  , True, False, True
# dream => dream  , True, False, False
# he => he  , True, False, True
# had => had  , True, False, True
# been => been  , True, False, True
# having => having , True, False, False
# . => .  , False, True, False
# It => It  , True, False, True
# had => had  , True, False, True
# been => been  , True, False, True
# a => a  , True, False, True
# good => good  , True, False, False
# one => one , True, False, True
# . => . , False, True, False
#
#  =>
#  , False, False, False
# There => There  , True, False, True
# had => had  , True, False, True
# been => been  , True, False, True
# a => a  , True, False, True
# flying => flying  , True, False, False
# motorcycle => motorcycle  , True, False, False
# in => in  , True, False, True
# it => it , True, False, True
# . => .  , False, True, False
# He => He  , True, False, True
# had => had  , True, False, True
# a => a  , True, False, True
# funny => funny  , True, False, False
# feeling => feeling  , True, False, False
# he => he , True, False, True
# ’d => ’d  , False, False, True
# had => had  , True, False, True
# the => the , True, False, True
#
#  =>
#  , False, False, False
# same => same  , True, False, True
# dream => dream  , True, False, False
# before => before , True, False, True
# . => . , False, True, False
#
#  =>
#  , False, False, False
# His => His  , True, False, True
# aunt => aunt  , True, False, False
# was => was  , True, False, True
# back => back  , True, False, True
# outside => outside  , True, False, False
# the => the  , True, False, True
# door => door , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# “ => “ , False, True, False
# Are => Are  , True, False, True
# you => you  , True, False, True
# up => up  , True, False, True
# yet => yet , True, False, True
# ? => ? , False, True, False
# ” => ”  , False, True, False
# she => she  , True, False, True
# demanded => demanded , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# “ => “ , False, True, False
# Nearly => Nearly , True, False, False
# , => , , False, True, False
# ” => ”  , False, True, False
# said => said  , True, False, False
# Harry => Harry , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# “ => “ , False, True, False
# Well => Well , True, False, True
# , => ,  , False, True, False
# get => get  , True, False, True
# a => a  , True, False, True
# move => move  , True, False, True
# on => on , True, False, True
# , => ,  , False, True, False
# I => I  , True, False, True
# want => want  , True, False, False
# you => you  , True, False, True
# to => to  , True, False, True
# look => look  , True, False, False
# after => after  , True, False, True
# the => the  , True, False, True
# bacon => bacon , True, False, False
# . => .  , False, True, False
# And => And  , True, False, True
# do => do , True, False, True
# n’t => n’t  , False, False, True
# you => you , True, False, True
#
#  =>
#  , False, False, False
# dare => dare  , True, False, False
# let => let  , True, False, False
# it => it  , True, False, True
# burn => burn , True, False, False
# , => ,  , False, True, False
# I => I  , True, False, True
# want => want  , True, False, False
# everything => everything  , True, False, True
# perfect => perfect  , True, False, False
# on => on  , True, False, True
# Duddy => Duddy , True, False, False
# ’s => ’s  , False, False, True
# birthday => birthday , True, False, False
# . => . , False, True, False
# ” => ” , False, True, False
#
#  =>
#  , False, False, False
# Harry => Harry  , True, False, False
# groaned => groaned , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# “ => “ , False, True, False
# What => What  , True, False, True
# did => did  , True, False, True
# you => you  , True, False, True
# say => say , True, False, True
# ? => ? , False, True, False
# ” => ”  , False, True, False
# his => his  , True, False, True
# aunt => aunt  , True, False, False
# snapped => snapped  , True, False, False
# through => through  , True, False, True
# the => the  , True, False, True
# door => door , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# “ => “ , False, True, False
# Nothing => Nothing , True, False, True
# , => ,  , False, True, False
# nothing => nothing , True, False, True
# … => … , False, True, False
# ” => ” , False, True, False
#
#  =>
#  , False, False, False
# Dudley => Dudley , True, False, False
# ’s => ’s  , False, False, True
# birthday => birthday  , True, False, False
# — => —  , False, True, False
# how => how  , True, False, True
# could => could  , True, False, True
# he => he  , True, False, True
# have => have  , True, False, True
# forgotten => forgotten , True, False, False
# ? => ?  , False, True, False
# Harry => Harry  , True, False, False
# got => got  , True, False, False
# slowly => slowly  , True, False, False
# out => out , True, False, True
#
#  =>
#  , False, False, False
# of => of  , True, False, True
# bed => bed  , True, False, False
# and => and  , True, False, True
# started => started  , True, False, False
# looking => looking  , True, False, False
# for => for  , True, False, True
# socks => socks , True, False, False
# . => .  , False, True, False
# He => He  , True, False, True
# found => found  , True, False, False
# a => a  , True, False, True
# pair => pair  , True, False, False
# under => under  , True, False, True
# his => his  , True, False, True
# bed => bed  , True, False, False
# and => and , True, False, True
# , => ,  , False, True, False
# after => after , True, False, True
#
#  =>
#  , False, False, False
# pulling => pulling  , True, False, False
# a => a  , True, False, True
# spider => spider  , True, False, False
# off => off  , True, False, True
# one => one  , True, False, True
# of => of  , True, False, True
# them => them , True, False, True
# , => ,  , False, True, False
# put => put  , True, False, True
# them => them  , True, False, True
# on => on , True, False, True
# . => .  , False, True, False
# Harry => Harry  , True, False, False
# was => was  , True, False, True
# used => used  , True, False, True
# to => to  , True, False, True
# spiders => spiders , True, False, False
# , => ,  , False, True, False
# because => because , True, False, True
#
#  =>
#  , False, False, False
# the => the  , True, False, True
# cupboard => cupboard  , True, False, False
# under => under  , True, False, True
# the => the  , True, False, True
# stairs => stairs  , True, False, False
# was => was  , True, False, True
# full => full  , True, False, True
# of => of  , True, False, True
# them => them , True, False, True
# , => ,  , False, True, False
# and => and  , True, False, True
# that => that  , True, False, True
# was => was  , True, False, True
# where => where  , True, False, True
# he => he  , True, False, True
# slept => slept , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# When => When  , True, False, True
# he => he  , True, False, True
# was => was  , True, False, True
# dressed => dressed  , True, False, False
# he => he  , True, False, True
# went => went  , True, False, False
# down => down  , True, False, True
# the => the  , True, False, True
# hall => hall  , True, False, False
# into => into  , True, False, True
# the => the  , True, False, True
# kitchen => kitchen , True, False, False
# . => .  , False, True, False
# The => The  , True, False, True
# table => table , True, False, False
#
#  =>
#  , False, False, False
# was => was  , True, False, True
# almost => almost  , True, False, True
# hidden => hidden  , True, False, False
# beneath => beneath  , True, False, False
# all => all  , True, False, True
# Dudley => Dudley , True, False, False
# ’s => ’s  , False, False, True
# birthday => birthday  , True, False, False
# presents => presents , True, False, False
# . => .  , False, True, False
# It => It  , True, False, True
# looked => looked  , True, False, False
# as => as  , True, False, True
# though => though , True, False, True
#
#  =>
#  , False, False, False
# Dudley => Dudley  , True, False, False
# had => had  , True, False, True
# gotten => gotten  , True, False, False
# the => the  , True, False, True
# new => new  , True, False, False
# computer => computer  , True, False, False
# he => he  , True, False, True
# wanted => wanted , True, False, False
# , => ,  , False, True, False
# not => not  , True, False, True
# to => to  , True, False, True
# mention => mention  , True, False, False
# the => the  , True, False, True
# second => second , True, False, False
#
#  =>
#  , False, False, False
# television => television  , True, False, False
# and => and  , True, False, True
# the => the  , True, False, True
# racing => racing  , True, False, False
# bike => bike , True, False, False
# . => .  , False, True, False
# Exactly => Exactly  , True, False, False
# why => why  , True, False, True
# Dudley => Dudley  , True, False, False
# wanted => wanted  , True, False, False
# a => a  , True, False, True
# racing => racing  , True, False, False
# bike => bike  , True, False, False
# was => was  , True, False, True
# a => a , True, False, True
#
#  =>
#  , False, False, False
# mystery => mystery  , True, False, False
# to => to  , True, False, True
# Harry => Harry , True, False, False
# , => ,  , False, True, False
# as => as  , True, False, True
# Dudley => Dudley  , True, False, False
# was => was  , True, False, True
# very => very  , True, False, True
# fat => fat  , True, False, False
# and => and  , True, False, True
# hated => hated  , True, False, False
# exercise => exercise  , True, False, False
# — => —  , False, True, False
# unless => unless  , True, False, True
# of => of  , True, False, True
# course => course , True, False, False
#
#  =>
#  , False, False, False
# it => it  , True, False, True
# involved => involved  , True, False, False
# punching => punching  , True, False, False
# somebody => somebody , True, False, False
# . => .  , False, True, False
# Dudley => Dudley , True, False, False
# ’s => ’s  , False, False, True
# favorite => favorite  , True, False, False
# punching => punching  , True, False, False
# bag => bag  , True, False, False
# was => was  , True, False, True
# Harry => Harry , True, False, False
# , => ,  , False, True, False
# but => but , True, False, True
#
#  =>
#  , False, False, False
# he => he  , True, False, True
# could => could , True, False, True
# n’t => n’t  , False, False, True
# often => often  , True, False, True
# catch => catch  , True, False, False
# him => him , True, False, True
# . => .  , False, True, False
# Harry => Harry  , True, False, False
# did => did , True, False, True
# n’t => n’t  , False, False, True
# look => look  , True, False, False
# it => it , True, False, True
# , => ,  , False, True, False
# but => but  , True, False, True
# he => he  , True, False, True
# was => was  , True, False, True
# very => very  , True, False, True
# fast => fast , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# Perhaps => Perhaps  , True, False, True
# it => it  , True, False, True
# had => had  , True, False, True
# something => something  , True, False, True
# to => to  , True, False, True
# do => do  , True, False, True
# with => with  , True, False, True
# living => living  , True, False, False
# in => in  , True, False, True
# a => a  , True, False, True
# dark => dark  , True, False, False
# cupboard => cupboard , True, False, False
# , => ,  , False, True, False
# but => but  , True, False, True
# Harry => Harry , True, False, False
#
#  =>
#  , False, False, False
# had => had  , True, False, True
# always => always  , True, False, True
# been => been  , True, False, True
# small => small  , True, False, False
# and => and  , True, False, True
# skinny => skinny  , True, False, False
# for => for  , True, False, True
# his => his  , True, False, True
# age => age , True, False, False
# . => .  , False, True, False
# He => He  , True, False, True
# looked => looked  , True, False, False
# even => even  , True, False, True
# smaller => smaller  , True, False, False
# and => and , True, False, True
#
#  =>
#  , False, False, False
# skinnier => skinnier  , True, False, False
# than => than  , True, False, True
# he => he  , True, False, True
# really => really  , True, False, True
# was => was  , True, False, True
# because => because  , True, False, True
# all => all  , True, False, True
# he => he  , True, False, True
# had => had  , True, False, True
# to => to  , True, False, True
# wear => wear  , True, False, False
# were => were  , True, False, True
# old => old  , True, False, False
# clothes => clothes  , True, False, False
# of => of , True, False, True
#
#  =>
#  , False, False, False
# Dudley => Dudley , True, False, False
# ’s => ’s , False, False, True
# , => ,  , False, True, False
# and => and  , True, False, True
# Dudley => Dudley  , True, False, False
# was => was  , True, False, True
# about => about  , True, False, True
# four => four  , True, False, True
# times => times  , True, False, False
# bigger => bigger  , True, False, False
# than => than  , True, False, True
# he => he  , True, False, True
# was => was , True, False, True
# . => .  , False, True, False
# Harry => Harry  , True, False, False
# had => had  , True, False, True
# a => a  , True, False, True
# thin => thin , True, False, False
#
#  =>
#  , False, False, False
# face => face , True, False, False
# , => ,  , False, True, False
# knobbly => knobbly  , True, False, False
# knees => knees , True, False, False
# , => ,  , False, True, False
# black => black  , True, False, False
# hair => hair , True, False, False
# , => ,  , False, True, False
# and => and  , True, False, True
# bright => bright  , True, False, False
# green => green  , True, False, False
# eyes => eyes , True, False, False
# . => .  , False, True, False
# He => He  , True, False, True
# wore => wore  , True, False, False
# round => round  , True, False, False
# glasses => glasses , True, False, False
#
#  =>
#  , False, False, False
# held => held  , True, False, False
# together => together  , True, False, True
# with => with  , True, False, True
# a => a  , True, False, True
# lot => lot  , True, False, False
# of => of  , True, False, True
# Scotch => Scotch  , True, False, False
# tape => tape  , True, False, False
# because => because  , True, False, True
# of => of  , True, False, True
# all => all  , True, False, True
# the => the  , True, False, True
# times => times  , True, False, False
# Dudley => Dudley  , True, False, False
# had => had , True, False, True
#
#  =>
#  , False, False, False
# punched => punched  , True, False, False
# him => him  , True, False, True
# on => on  , True, False, True
# the => the  , True, False, True
# nose => nose , True, False, False
# . => .  , False, True, False
# The => The  , True, False, True
# only => only  , True, False, True
# thing => thing  , True, False, False
# Harry => Harry  , True, False, False
# liked => liked  , True, False, False
# about => about  , True, False, True
# his => his  , True, False, True
# own => own  , True, False, True
# appearance => appearance , True, False, False
#
#  =>
#  , False, False, False
# was => was  , True, False, True
# a => a  , True, False, True
# very => very  , True, False, True
# thin => thin  , True, False, False
# scar => scar  , True, False, False
# on => on  , True, False, True
# his => his  , True, False, True
# forehead => forehead  , True, False, False
# that => that  , True, False, True
# was => was  , True, False, True
# shaped => shaped  , True, False, False
# like => like  , True, False, False
# a => a  , True, False, True
# bolt => bolt  , True, False, False
# of => of  , True, False, True
# lightning => lightning , True, False, False
# . => .  , False, True, False
# He => He , True, False, True
#
#  =>
#  , False, False, False
# had => had  , True, False, True
# had => had  , True, False, True
# it => it  , True, False, True
# as => as  , True, False, True
# long => long  , True, False, False
# as => as  , True, False, True
# he => he  , True, False, True
# could => could  , True, False, True
# remember => remember , True, False, False
# , => ,  , False, True, False
# and => and  , True, False, True
# the => the  , True, False, True
# first => first  , True, False, True
# question => question  , True, False, False
# he => he  , True, False, True
# could => could  , True, False, True
# ever => ever , True, False, True
#
#  =>
#  , False, False, False
# remember => remember  , True, False, False
# asking => asking  , True, False, False
# his => his  , True, False, True
# Aunt => Aunt  , True, False, False
# Petunia => Petunia  , True, False, False
# was => was  , True, False, True
# how => how  , True, False, True
# he => he  , True, False, True
# had => had  , True, False, True
# gotten => gotten  , True, False, False
# it => it , True, False, True
# . => . , False, True, False
#
#  =>
#  , False, False, False
# “ => “ , False, True, False
# In => In  , True, False, True
# the => the  , True, False, True
# car => car  , True, False, False
# crash => crash  , True, False, False
# when => when  , True, False, True
# your => your  , True, False, True
# parents => parents  , True, False, False
# died => died , True, False, False
# , => , , False, True, False
# ” => ”  , False, True, False
# she => she  , True, False, True
# had => had  , True, False, True
# said => said , True, False, False
# . => .  , False, True, False
# “ => “ , False, True, False
# And => And  , True, False, True
# do => do , True, False, True
# n’t => n’t  , False, False, True
# ask => ask , True, False, False
#
#  =>
#  , False, False, False
# questions => questions , True, False, False
# . => . , False, True, False
# ” => ” , False, True, False
#
#  =>
#  , False, False, False
# Do => Do , True, False, True
# n’t => n’t  , False, False, True
# ask => ask  , True, False, False
# questions => questions  , True, False, False
# — => —  , False, True, False
# that => that  , True, False, True
# was => was  , True, False, True
# the => the  , True, False, True
# first => first  , True, False, True
# rule => rule  , True, False, False
# for => for  , True, False, True
# a => a  , True, False, True
# quiet => quiet  , True, False, False
# life => life  , True, False, False
# with => with  , True, False, True
# the => the , True, False, True
#
#  =>
#  , False, False, False
# Dursleys => Dursleys , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# Uncle => Uncle  , True, False, False
# Vernon => Vernon  , True, False, False
# entered => entered  , True, False, False
# the => the  , True, False, True
# kitchen => kitchen  , True, False, False
# as => as  , True, False, True
# Harry => Harry  , True, False, False
# was => was  , True, False, True
# turning => turning  , True, False, False
# over => over  , True, False, True
# the => the  , True, False, True
# bacon => bacon , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# “ => “ , False, True, False
# Comb => Comb  , True, False, False
# your => your  , True, False, True
# hair => hair , True, False, False
# ! => ! , False, True, False
# ” => ”  , False, True, False
# he => he  , True, False, True
# barked => barked , True, False, False
# , => ,  , False, True, False
# by => by  , True, False, True
# way => way  , True, False, False
# of => of  , True, False, True
# a => a  , True, False, True
# morning => morning  , True, False, False
# greeting => greeting , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# About => About  , True, False, True
# once => once  , True, False, True
# a => a  , True, False, True
# week => week , True, False, False
# , => ,  , False, True, False
# Uncle => Uncle  , True, False, False
# Vernon => Vernon  , True, False, False
# looked => looked  , True, False, False
# over => over  , True, False, True
# the => the  , True, False, True
# top => top  , True, False, True
# of => of  , True, False, True
# his => his  , True, False, True
# newspaper => newspaper , True, False, False
#
#  =>
#  , False, False, False
# and => and  , True, False, True
# shouted => shouted  , True, False, False
# that => that  , True, False, True
# Harry => Harry  , True, False, False
# needed => needed  , True, False, False
# a => a  , True, False, True
# haircut => haircut , True, False, False
# . => .  , False, True, False
# Harry => Harry  , True, False, False
# must => must  , True, False, True
# have => have  , True, False, True
# had => had  , True, False, True
# more => more  , True, False, True
# haircuts => haircuts  , True, False, False
# than => than , True, False, True
#
#  =>
#  , False, False, False
# the => the  , True, False, True
# rest => rest  , True, False, False
# of => of  , True, False, True
# the => the  , True, False, True
# boys => boys  , True, False, False
# in => in  , True, False, True
# his => his  , True, False, True
# class => class  , True, False, False
# put => put  , True, False, True
# together => together , True, False, True
# , => ,  , False, True, False
# but => but  , True, False, True
# it => it  , True, False, True
# made => made  , True, False, True
# no => no  , True, False, True
# difference => difference , True, False, False
# , => ,  , False, True, False
# his => his  , True, False, True
# hair => hair , True, False, False
#
#  =>
#  , False, False, False
# simply => simply  , True, False, False
# grew => grew  , True, False, False
# that => that  , True, False, True
# way => way  , True, False, False
# — => —  , False, True, False
# all => all  , True, False, True
# over => over  , True, False, True
# the => the  , True, False, True
# place => place , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# Harry => Harry  , True, False, False
# was => was  , True, False, True
# frying => frying  , True, False, False
# eggs => eggs  , True, False, False
# by => by  , True, False, True
# the => the  , True, False, True
# time => time  , True, False, False
# Dudley => Dudley  , True, False, False
# arrived => arrived  , True, False, False
# in => in  , True, False, True
# the => the  , True, False, True
# kitchen => kitchen  , True, False, False
# with => with  , True, False, True
# his => his , True, False, True
#
#  =>
#  , False, False, False
# mother => mother , True, False, False
# . => .  , False, True, False
# Dudley => Dudley  , True, False, False
# looked => looked  , True, False, False
# a => a  , True, False, True
# lot => lot  , True, False, False
# like => like  , True, False, False
# Uncle => Uncle  , True, False, False
# Vernon => Vernon , True, False, False
# . => .  , False, True, False
# He => He  , True, False, True
# had => had  , True, False, True
# a => a  , True, False, True
# large => large  , True, False, False
# pink => pink  , True, False, False
# face => face , True, False, False
# , => ,  , False, True, False
# not => not , True, False, True
#
#  =>
#  , False, False, False
# much => much  , True, False, True
# neck => neck , True, False, False
# , => ,  , False, True, False
# small => small , True, False, False
# , => ,  , False, True, False
# watery => watery  , True, False, False
# blue => blue  , True, False, False
# eyes => eyes , True, False, False
# , => ,  , False, True, False
# and => and  , True, False, True
# thick => thick  , True, False, False
# blond => blond  , True, False, False
# hair => hair  , True, False, False
# that => that  , True, False, True
# lay => lay  , True, False, False
# smoothly => smoothly  , True, False, False
# on => on , True, False, True
#
#  =>
#  , False, False, False
# his => his  , True, False, True
# thick => thick , True, False, False
# , => ,  , False, True, False
# fat => fat  , True, False, False
# head => head , True, False, False
# . => .  , False, True, False
# Aunt => Aunt  , True, False, False
# Petunia => Petunia  , True, False, False
# often => often  , True, False, True
# said => said  , True, False, False
# that => that  , True, False, True
# Dudley => Dudley  , True, False, False
# looked => looked  , True, False, False
# like => like  , True, False, False
# a => a  , True, False, True
# baby => baby  , True, False, False
# angel => angel , True, False, False
#
#  =>
#  , False, False, False
# — => —  , False, True, False
# Harry => Harry  , True, False, False
# often => often  , True, False, True
# said => said  , True, False, False
# that => that  , True, False, True
# Dudley => Dudley  , True, False, False
# looked => looked  , True, False, False
# like => like  , True, False, False
# a => a  , True, False, True
# pig => pig  , True, False, False
# in => in  , True, False, True
# a => a  , True, False, True
# wig => wig , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# Harry => Harry  , True, False, False
# put => put  , True, False, True
# the => the  , True, False, True
# plates => plates  , True, False, False
# of => of  , True, False, True
# egg => egg  , True, False, False
# and => and  , True, False, True
# bacon => bacon  , True, False, False
# on => on  , True, False, True
# the => the  , True, False, True
# table => table , True, False, False
# , => ,  , False, True, False
# which => which  , True, False, True
# was => was  , True, False, True
# difficult => difficult  , True, False, False
# as => as , True, False, True
#
#  =>
#  , False, False, False
# there => there  , True, False, True
# was => was , True, False, True
# n’t => n’t  , False, False, True
# much => much  , True, False, True
# room => room , True, False, False
# . => .  , False, True, False
# Dudley => Dudley , True, False, False
# , => ,  , False, True, False
# meanwhile => meanwhile , True, False, True
# , => ,  , False, True, False
# was => was  , True, False, True
# counting => counting  , True, False, False
# his => his  , True, False, True
# presents => presents , True, False, False
# . => .  , False, True, False
# His => His , True, False, True
#
#  =>
#  , False, False, False
# face => face  , True, False, False
# fell => fell , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# “ => “ , False, True, False
# Thirty => Thirty , True, False, False
# - => - , False, True, False
# six => six , True, False, True
# , => , , False, True, False
# ” => ”  , False, True, False
# he => he  , True, False, True
# said => said , True, False, False
# , => ,  , False, True, False
# looking => looking  , True, False, False
# up => up  , True, False, True
# at => at  , True, False, True
# his => his  , True, False, True
# mother => mother  , True, False, False
# and => and  , True, False, True
# father => father , True, False, False
# . => .  , False, True, False
# “ => “ , False, True, False
# That => That , True, False, True
# ’s => ’s  , False, False, True
# two => two , True, False, True
#
#  =>
#  , False, False, False
# less => less  , True, False, True
# than => than  , True, False, True
# last => last  , True, False, True
# year => year , True, False, False
# . => . , False, True, False
# ” => ” , False, True, False
#
#  =>
#  , False, False, False
# “ => “ , False, True, False
# Darling => Darling , True, False, False
# , => ,  , False, True, False
# you => you  , True, False, True
# have => have , True, False, True
# n’t => n’t  , False, False, True
# counted => counted  , True, False, False
# Auntie => Auntie  , True, False, False
# Marge => Marge , True, False, False
# ’s => ’s  , False, False, True
# present => present , True, False, False
# , => ,  , False, True, False
# see => see , True, False, True
# , => ,  , False, True, False
# it => it , True, False, True
# ’s => ’s  , False, False, True
# here => here , True, False, True
#
#  =>
#  , False, False, False
# under => under  , True, False, True
# this => this  , True, False, True
# big => big  , True, False, False
# one => one  , True, False, True
# from => from  , True, False, True
# Mummy => Mummy  , True, False, False
# and => and  , True, False, True
# Daddy => Daddy , True, False, False
# . => . , False, True, False
# ” => ” , False, True, False
#
#  =>
#  , False, False, False
# “ => “ , False, True, False
# All => All  , True, False, True
# right => right , True, False, False
# , => ,  , False, True, False
# thirty => thirty , True, False, False
# - => - , False, True, False
# seven => seven  , True, False, False
# then => then , True, False, True
# , => , , False, True, False
# ” => ”  , False, True, False
# said => said  , True, False, False
# Dudley => Dudley , True, False, False
# , => ,  , False, True, False
# going => going  , True, False, False
# red => red  , True, False, False
# in => in  , True, False, True
# the => the  , True, False, True
# face => face , True, False, False
# . => .  , False, True, False
# Harry => Harry , True, False, False
# , => , , False, True, False
#
#  =>
#  , False, False, False
# who => who  , True, False, True
# could => could  , True, False, True
# see => see  , True, False, True
# a => a  , True, False, True
# huge => huge  , True, False, False
# Dudley => Dudley  , True, False, False
# tantrum => tantrum  , True, False, False
# coming => coming  , True, False, False
# on => on , True, False, True
# , => ,  , False, True, False
# began => began  , True, False, False
# wolfing => wolfing  , True, False, False
# down => down  , True, False, True
# his => his  , True, False, True
# bacon => bacon , True, False, False
#
#  =>
#  , False, False, False
# as => as  , True, False, True
# fast => fast  , True, False, False
# as => as  , True, False, True
# possible => possible  , True, False, False
# in => in  , True, False, True
# case => case  , True, False, False
# Dudley => Dudley  , True, False, False
# turned => turned  , True, False, False
# the => the  , True, False, True
# table => table  , True, False, False
# over => over , True, False, True
# . => . , False, True, False
#
#  =>
#  , False, False, False
# Aunt => Aunt  , True, False, False
# Petunia => Petunia  , True, False, False
# obviously => obviously  , True, False, False
# scented => scented  , True, False, False
# danger => danger , True, False, False
# , => ,  , False, True, False
# too => too , True, False, True
# , => ,  , False, True, False
# because => because  , True, False, True
# she => she  , True, False, True
# said => said  , True, False, False
# quickly => quickly , True, False, False
# , => , , False, True, False
#
#  =>
#  , False, False, False
# “ => “ , False, True, False
# And => And  , True, False, True
# we => we , True, False, True
# ’ll => ’ll  , False, False, True
# buy => buy  , True, False, False
# you => you  , True, False, True
# another => another  , True, False, True
# two => two  , True, False, True
# presents => presents  , True, False, False
# while => while  , True, False, True
# we => we , True, False, True
# ’re => ’re  , False, False, True
# out => out  , True, False, True
# today => today , True, False, False
# . => .  , False, True, False
# How => How , True, False, True
# ’s => ’s  , False, False, True
# that => that , True, False, True
# , => , , False, True, False
#
#  =>
#  , False, False, False
# popkin => popkin , True, False, False
# ? => ?  , False, True, False
# Two => Two  , True, False, True
# more => more  , True, False, True
# presents => presents , True, False, False
# . => .  , False, True, False
# Is => Is  , True, False, True
# that => that  , True, False, True
# all => all  , True, False, True
# right => right , True, False, False
# ” => ” , False, True, False
#
#  =>
#  , False, False, False
# Dudley => Dudley  , True, False, False
# thought => thought  , True, False, False
# for => for  , True, False, True
# a => a  , True, False, True
# moment => moment , True, False, False
# . => .  , False, True, False
# It => It  , True, False, True
# looked => looked  , True, False, False
# like => like  , True, False, False
# hard => hard  , True, False, False
# work => work , True, False, False
# . => .  , False, True, False
# Finally => Finally  , True, False, False
# he => he  , True, False, True
# said => said , True, False, False
#
#  =>
#  , False, False, False
# slowly => slowly , True, False, False
# , => ,  , False, True, False
# “ => “ , False, True, False
# So => So  , True, False, True
# I => I , True, False, True
# ’ll => ’ll  , False, False, True
# have => have  , True, False, True
# thirty => thirty , True, False, False
# ... => ... , False, True, False
# thirty => thirty , True, False, False
# ... => ... , False, True, False
# ” => ” , False, True, False
#
#  =>
#  , False, False, False
# “ => “ , False, True, False
# Thirty => Thirty , True, False, False
# - => - , False, True, False
# nine => nine , True, False, True
# , => ,  , False, True, False
# sweetums => sweetums , True, False, False
# , => , , False, True, False
# ” => ”  , False, True, False
# said => said  , True, False, False
# Aunt => Aunt  , True, False, False
# Petunia => Petunia , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# “ => “ , False, True, False
# Oh => Oh , True, False, False
# . => . , False, True, False
# ” => ”  , False, True, False
# Dudley => Dudley  , True, False, False
# sat => sat  , True, False, False
# down => down  , True, False, True
# heavily => heavily  , True, False, False
# and => and  , True, False, True
# grabbed => grabbed  , True, False, False
# the => the  , True, False, True
# nearest => nearest  , True, False, False
# parcel => parcel , True, False, False
# . => .  , False, True, False
# “ => “ , False, True, False
# All => All  , True, False, True
# right => right , True, False, False
#
#  =>
#  , False, False, False
# then => then , True, False, True
# . => . , False, True, False
# ” => ” , False, True, False
#
#  =>
#  , False, False, False
# Uncle => Uncle  , True, False, False
# Vernon => Vernon  , True, False, False
# chuckled => chuckled , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# “ => “ , False, True, False
# Little => Little  , True, False, False
# tyke => tyke  , True, False, False
# wants => wants  , True, False, False
# his => his  , True, False, True
# money => money , True, False, False
# ’s => ’s  , False, False, True
# worth => worth , True, False, False
# , => ,  , False, True, False
# just => just  , True, False, True
# like => like  , True, False, False
# his => his  , True, False, True
# father => father , True, False, False
# . => .  , False, True, False
# ’ => ’ , False, True, False
# Atta => Atta  , True, False, False
# boy => boy , True, False, False
# , => , , False, True, False
#
#  =>
#  , False, False, False
# Dudley => Dudley , True, False, False
# ! => ! , False, True, False
# ” => ”  , False, True, False
# He => He  , True, False, True
# ruffled => ruffled  , True, False, False
# Dudley => Dudley , True, False, False
# ’s => ’s  , False, False, True
# hair => hair , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# At => At  , True, False, True
# that => that  , True, False, True
# moment => moment  , True, False, False
# the => the  , True, False, True
# telephone => telephone  , True, False, False
# rang => rang  , True, False, False
# and => and  , True, False, True
# Aunt => Aunt  , True, False, False
# Petunia => Petunia  , True, False, False
# went => went  , True, False, False
# to => to  , True, False, True
# answer => answer  , True, False, False
# it => it , True, False, True
#
#  =>
#  , False, False, False
# while => while  , True, False, True
# Harry => Harry  , True, False, False
# and => and  , True, False, True
# Uncle => Uncle  , True, False, False
# Vernon => Vernon  , True, False, False
# watched => watched  , True, False, False
# Dudley => Dudley  , True, False, False
# unwrap => unwrap  , True, False, False
# the => the  , True, False, True
# racing => racing  , True, False, False
# bike => bike , True, False, False
# , => ,  , False, True, False
# a => a  , True, False, True
# video => video , True, False, False
#
#  =>
#  , False, False, False
# camera => camera , True, False, False
# , => ,  , False, True, False
# a => a  , True, False, True
# remote => remote  , True, False, False
# control => control  , True, False, False
# airplane => airplane , True, False, False
# , => ,  , False, True, False
# sixteen => sixteen  , True, False, False
# new => new  , True, False, False
# computer => computer  , True, False, False
# games => games , True, False, False
# , => ,  , False, True, False
# and => and  , True, False, True
# a => a  , True, False, True
# VCR => VCR , True, False, False
# . => .  , False, True, False
# He => He , True, False, True
#
#  =>
#  , False, False, False
# was => was  , True, False, True
# ripping => ripping  , True, False, False
# the => the  , True, False, True
# paper => paper  , True, False, False
# off => off  , True, False, True
# a => a  , True, False, True
# gold => gold  , True, False, False
# wristwatch => wristwatch  , True, False, False
# when => when  , True, False, True
# Aunt => Aunt  , True, False, False
# Petunia => Petunia  , True, False, False
# came => came  , True, False, False
# back => back  , True, False, True
# from => from , True, False, True
#
#  =>
#  , False, False, False
# the => the  , True, False, True
# telephone => telephone  , True, False, False
# looking => looking  , True, False, False
# both => both  , True, False, True
# angry => angry  , True, False, False
# and => and  , True, False, True
# worried => worried , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# “ => “ , False, True, False
# Bad => Bad  , True, False, False
# news => news , True, False, False
# , => ,  , False, True, False
# Vernon => Vernon , True, False, False
# , => , , False, True, False
# ” => ”  , False, True, False
# she => she  , True, False, True
# said => said , True, False, False
# . => .  , False, True, False
# “ => “ , False, True, False
# Mrs. => Mrs.  , False, False, False
# Figg => Figg , True, False, False
# ’s => ’s  , False, False, True
# broken => broken  , True, False, False
# her => her  , True, False, True
# leg => leg , True, False, False
# . => .  , False, True, False
# She => She  , True, False, True
# ca => ca , True, False, True
# n’t => n’t , False, False, True
#
#  =>
#  , False, False, False
# take => take  , True, False, True
# him => him , True, False, True
# . => . , False, True, False
# ” => ”  , False, True, False
# She => She  , True, False, True
# jerked => jerked  , True, False, False
# her => her  , True, False, True
# head => head  , True, False, False
# in => in  , True, False, True
# Harry => Harry , True, False, False
# ’s => ’s  , False, False, True
# direction => direction , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# Dudley => Dudley , True, False, False
# ’s => ’s  , False, False, True
# mouth => mouth  , True, False, False
# fell => fell  , True, False, False
# open => open  , True, False, False
# in => in  , True, False, True
# horror => horror , True, False, False
# , => ,  , False, True, False
# but => but  , True, False, True
# Harry => Harry , True, False, False
# ’s => ’s  , False, False, True
# heart => heart  , True, False, False
# gave => gave  , True, False, False
# a => a  , True, False, True
# leap => leap , True, False, False
# . => .  , False, True, False
# Every => Every , True, False, True
#
#  =>
#  , False, False, False
# year => year  , True, False, False
# on => on  , True, False, True
# Dudley => Dudley , True, False, False
# ’s => ’s  , False, False, True
# birthday => birthday , True, False, False
# , => ,  , False, True, False
# his => his  , True, False, True
# ...
# say => say , True, False, True
# , => , , False, True, False
#
#  =>
#  , False, False, False
# “ => “ , False, True, False
# Go => Go  , True, False, True
# — => —  , False, True, False
# cupboard => cupboard  , True, False, False
# — => —  , False, True, False
# stay => stay  , True, False, False
# — => —  , False, True, False
# no => no  , True, False, True
# meals => meals , True, False, False
# , => , , False, True, False
# ” => ”  , False, True, False
# before => before  , True, False, True
# he => he  , True, False, True
# collapsed => collapsed  , True, False, False
# into => into  , True, False, True
# a => a  , True, False, True
# chair => chair , True, False, False
# , => ,  , False, True, False
# and => and , True, False, True
#
#  =>
#  , False, False, False
# Aunt => Aunt  , True, False, False
# Petunia => Petunia  , True, False, False
# had => had  , True, False, True
# to => to  , True, False, True
# run => run  , True, False, False
# and => and  , True, False, True
# get => get  , True, False, True
# him => him  , True, False, True
# a => a  , True, False, True
# large => large  , True, False, False
# brandy => brandy , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# Harry => Harry  , True, False, False
# lay => lay  , True, False, False
# in => in  , True, False, True
# his => his  , True, False, True
# dark => dark  , True, False, False
# cupboard => cupboard  , True, False, False
# much => much  , True, False, True
# later => later , True, False, False
# , => ,  , False, True, False
# wishing => wishing  , True, False, False
# he => he  , True, False, True
# had => had  , True, False, True
# a => a  , True, False, True
# watch => watch , True, False, False
# . => .  , False, True, False
# He => He  , True, False, True
# did => did , True, False, True
# n’t => n’t , False, False, True
#
#  =>
#  , False, False, False
# know => know  , True, False, False
# what => what  , True, False, True
# time => time  , True, False, False
# it => it  , True, False, True
# was => was  , True, False, True
# and => and  , True, False, True
# he => he  , True, False, True
# could => could , True, False, True
# n’t => n’t  , False, False, True
# be => be  , True, False, True
# sure => sure  , True, False, False
# the => the  , True, False, True
# Dursleys => Dursleys  , True, False, False
# were => were  , True, False, True
# asleep => asleep  , True, False, False
# yet => yet , True, False, True
# . => . , False, True, False
#
#  =>
#  , False, False, False
# Until => Until  , True, False, True
# they => they  , True, False, True
# were => were , True, False, True
# , => ,  , False, True, False
# he => he  , True, False, True
# could => could , True, False, True
# n’t => n’t  , False, False, True
# risk => risk  , True, False, False
# sneaking => sneaking  , True, False, False
# to => to  , True, False, True
# the => the  , True, False, True
# kitchen => kitchen  , True, False, False
# for => for  , True, False, True
# some => some  , True, False, True
# food => food , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# He => He , True, False, True
# ’d => ’d  , False, False, True
# lived => lived  , True, False, False
# with => with  , True, False, True
# the => the  , True, False, True
# Dursleys => Dursleys  , True, False, False
# almost => almost  , True, False, True
# ten => ten  , True, False, True
# years => years , True, False, False
# , => ,  , False, True, False
# ten => ten  , True, False, True
# miserable => miserable  , True, False, False
# years => years , True, False, False
# , => ,  , False, True, False
# as => as , True, False, True
#
#  =>
#  , False, False, False
# long => long  , True, False, False
# as => as  , True, False, True
# he => he  , True, False, True
# could => could  , True, False, True
# remember => remember , True, False, False
# , => ,  , False, True, False
# ever => ever  , True, False, True
# since => since  , True, False, True
# he => he , True, False, True
# ’d => ’d  , False, False, True
# been => been  , True, False, True
# a => a  , True, False, True
# baby => baby  , True, False, False
# and => and  , True, False, True
# his => his  , True, False, True
# parents => parents  , True, False, False
# had => had  , True, False, True
# died => died , True, False, False
#
#  =>
#  , False, False, False
# in => in  , True, False, True
# that => that  , True, False, True
# car => car  , True, False, False
# crash => crash , True, False, False
# . => .  , False, True, False
# He => He  , True, False, True
# could => could , True, False, True
# n’t => n’t  , False, False, True
# remember => remember  , True, False, False
# being => being  , True, False, True
# in => in  , True, False, True
# the => the  , True, False, True
# car => car  , True, False, False
# when => when  , True, False, True
# his => his  , True, False, True
# parents => parents  , True, False, False
# had => had , True, False, True
#
#  =>
#  , False, False, False
# died => died , True, False, False
# . => .  , False, True, False
# Sometimes => Sometimes , True, False, True
# , => ,  , False, True, False
# when => when  , True, False, True
# he => he  , True, False, True
# strained => strained  , True, False, False
# his => his  , True, False, True
# memory => memory  , True, False, False
# during => during  , True, False, True
# long => long  , True, False, False
# hours => hours  , True, False, False
# in => in  , True, False, True
# his => his , True, False, True
#
#  =>
#  , False, False, False
# cupboard => cupboard , True, False, False
# , => ,  , False, True, False
# he => he  , True, False, True
# came => came  , True, False, False
# up => up  , True, False, True
# with => with  , True, False, True
# a => a  , True, False, True
# strange => strange  , True, False, False
# vision => vision , True, False, False
# : => :  , False, True, False
# a => a  , True, False, True
# blinding => blinding  , True, False, False
# flash => flash  , True, False, False
# of => of  , True, False, True
# green => green  , True, False, False
# light => light  , True, False, False
# and => and  , True, False, True
# a => a , True, False, True
#
#  =>
#  , False, False, False
# burning => burning  , True, False, False
# pain => pain  , True, False, False
# on => on  , True, False, True
# his => his  , True, False, True
# forehead => forehead , True, False, False
# . => .  , False, True, False
# This => This , True, False, True
# , => ,  , False, True, False
# he => he  , True, False, True
# supposed => supposed , True, False, False
# , => ,  , False, True, False
# was => was  , True, False, True
# the => the  , True, False, True
# crash => crash , True, False, False
# , => ,  , False, True, False
# though => though  , True, False, True
# he => he , True, False, True
#
#  =>
#  , False, False, False
# could => could , True, False, True
# n’t => n’t  , False, False, True
# imagine => imagine  , True, False, False
# where => where  , True, False, True
# all => all  , True, False, True
# the => the  , True, False, True
# green => green  , True, False, False
# light => light  , True, False, False
# came => came  , True, False, False
# from => from , True, False, True
# . => .  , False, True, False
# He => He  , True, False, True
# could => could , True, False, True
# n’t => n’t  , False, False, True
# remember => remember  , True, False, False
# his => his , True, False, True
#
#  =>
#  , False, False, False
# parents => parents  , True, False, False
# at => at  , True, False, True
# all => all , True, False, True
# . => .  , False, True, False
# His => His  , True, False, True
# aunt => aunt  , True, False, False
# and => and  , True, False, True
# uncle => uncle  , True, False, False
# never => never  , True, False, True
# spoke => spoke  , True, False, False
# about => about  , True, False, True
# them => them , True, False, True
# , => ,  , False, True, False
# and => and  , True, False, True
# of => of  , True, False, True
# course => course  , True, False, False
# he => he  , True, False, True
# was => was , True, False, True
#
#  =>
#  , False, False, False
# forbidden => forbidden  , True, False, False
# to => to  , True, False, True
# ask => ask  , True, False, False
# questions => questions , True, False, False
# . => .  , False, True, False
# There => There  , True, False, True
# were => were  , True, False, True
# no => no  , True, False, True
# photographs => photographs  , True, False, False
# of => of  , True, False, True
# them => them  , True, False, True
# in => in  , True, False, True
# the => the  , True, False, True
# house => house , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# When => When  , True, False, True
# he => he  , True, False, True
# had => had  , True, False, True
# been => been  , True, False, True
# younger => younger , True, False, False
# , => ,  , False, True, False
# Harry => Harry  , True, False, False
# had => had  , True, False, True
# dreamed => dreamed  , True, False, False
# and => and  , True, False, True
# dreamed => dreamed  , True, False, False
# of => of  , True, False, True
# some => some , True, False, True
#
#  =>
#  , False, False, False
# unknown => unknown  , True, False, False
# relation => relation  , True, False, False
# coming => coming  , True, False, False
# to => to  , True, False, True
# take => take  , True, False, True
# him => him  , True, False, True
# away => away , True, False, False
# , => ,  , False, True, False
# but => but  , True, False, True
# it => it  , True, False, True
# had => had  , True, False, True
# never => never  , True, False, True
# happened => happened , True, False, False
# ; => ;  , False, True, False
# the => the , True, False, True
#
#  =>
#  , False, False, False
# Dursleys => Dursleys  , True, False, False
# were => were  , True, False, True
# his => his  , True, False, True
# only => only  , True, False, True
# family => family , True, False, False
# . => .  , False, True, False
# Yet => Yet  , True, False, True
# sometimes => sometimes  , True, False, True
# he => he  , True, False, True
# thought => thought  , True, False, False
# ( => ( , False, True, False
# or => or  , True, False, True
# maybe => maybe  , True, False, False
# hoped => hoped , True, False, False
# ) => )  , False, True, False
# that => that , True, False, True
#
#  =>
#  , False, False, False
# strangers => strangers  , True, False, False
# in => in  , True, False, True
# the => the  , True, False, True
# street => street  , True, False, False
# seemed => seemed  , True, False, True
# to => to  , True, False, True
# know => know  , True, False, False
# him => him , True, False, True
# . => .  , False, True, False
# Very => Very  , True, False, True
# strange => strange  , True, False, False
# strangers => strangers  , True, False, False
# they => they  , True, False, True
# were => were , True, False, True
# , => , , False, True, False
#
#  =>
#  , False, False, False
# too => too , True, False, True
# . => .  , False, True, False
# A => A  , True, False, True
# tiny => tiny  , True, False, False
# man => man  , True, False, False
# in => in  , True, False, True
# a => a  , True, False, True
# violet => violet  , True, False, False
# top => top  , True, False, True
# hat => hat  , True, False, False
# had => had  , True, False, True
# bowed => bowed  , True, False, False
# to => to  , True, False, True
# him => him  , True, False, True
# once => once  , True, False, True
# while => while  , True, False, True
# out => out  , True, False, True
# shopping => shopping , True, False, False
#
#  =>
#  , False, False, False
# with => with  , True, False, True
# Aunt => Aunt  , True, False, False
# Petunia => Petunia  , True, False, False
# and => and  , True, False, True
# Dudley => Dudley , True, False, False
# . => .  , False, True, False
# After => After  , True, False, True
# asking => asking  , True, False, False
# Harry => Harry  , True, False, False
# furiously => furiously  , True, False, False
# if => if  , True, False, True
# he => he  , True, False, True
# knew => knew  , True, False, False
# the => the  , True, False, True
# man => man , True, False, False
# , => , , False, True, False
#
#  =>
#  , False, False, False
# Aunt => Aunt  , True, False, False
# Petunia => Petunia  , True, False, False
# had => had  , True, False, True
# rushed => rushed  , True, False, False
# them => them  , True, False, True
# out => out  , True, False, True
# of => of  , True, False, True
# the => the  , True, False, True
# shop => shop  , True, False, False
# without => without  , True, False, True
# buying => buying  , True, False, False
# anything => anything , True, False, True
# . => .  , False, True, False
# A => A  , True, False, True
# wild- => wild- , False, False, False
#
#  =>
#  , False, False, False
# looking => looking  , True, False, False
# old => old  , True, False, False
# woman => woman  , True, False, False
# dressed => dressed  , True, False, False
# all => all  , True, False, True
# in => in  , True, False, True
# green => green  , True, False, False
# had => had  , True, False, True
# waved => waved  , True, False, False
# merrily => merrily  , True, False, False
# at => at  , True, False, True
# him => him  , True, False, True
# once => once  , True, False, True
# on => on  , True, False, True
# a => a  , True, False, True
# bus => bus , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# A => A  , True, False, True
# bald => bald  , True, False, False
# man => man  , True, False, False
# in => in  , True, False, True
# a => a  , True, False, True
# very => very  , True, False, True
# long => long  , True, False, False
# purple => purple  , True, False, False
# coat => coat  , True, False, False
# had => had  , True, False, True
# actually => actually  , True, False, False
# shaken => shaken  , True, False, False
# his => his  , True, False, True
# hand => hand  , True, False, False
# in => in  , True, False, True
# the => the  , True, False, True
# street => street , True, False, False
#
#  =>
#  , False, False, False
# the => the  , True, False, True
# other => other  , True, False, True
# day => day  , True, False, False
# and => and  , True, False, True
# then => then  , True, False, True
# walked => walked  , True, False, False
# away => away  , True, False, False
# without => without  , True, False, True
# a => a  , True, False, True
# word => word , True, False, False
# . => .  , False, True, False
# The => The  , True, False, True
# weirdest => weirdest  , True, False, False
# thing => thing  , True, False, False
# about => about  , True, False, True
# all => all , True, False, True
#
#  =>
#  , False, False, False
# these => these  , True, False, True
# people => people  , True, False, False
# was => was  , True, False, True
# the => the  , True, False, True
# way => way  , True, False, False
# they => they  , True, False, True
# seemed => seemed  , True, False, True
# to => to  , True, False, True
# vanish => vanish  , True, False, False
# the => the  , True, False, True
# second => second  , True, False, False
# Harry => Harry  , True, False, False
# tried => tried  , True, False, False
# to => to  , True, False, True
# get => get  , True, False, True
# a => a , True, False, True
#
#  =>
#  , False, False, False
# closer => closer  , True, False, False
# look => look , True, False, False
# . => . , False, True, False
#
#  =>
#  , False, False, False
# At => At  , True, False, True
# school => school , True, False, False
# , => ,  , False, True, False
# Harry => Harry  , True, False, False
# had => had  , True, False, True
# no => no  , True, False, True
# one => one , True, False, True
# . => .  , False, True, False
# Everybody => Everybody  , True, False, False
# knew => knew  , True, False, False
# that => that  , True, False, True
# Dudley => Dudley , True, False, False
# ’s => ’s  , False, False, True
# gang => gang  , True, False, False
# hated => hated , True, False, False
#
#  =>
#  , False, False, False
# that => that  , True, False, True
# odd => odd  , True, False, False
# Harry => Harry  , True, False, False
# Potter => Potter  , True, False, False
# in => in  , True, False, True
# his => his  , True, False, True
# baggy => baggy  , True, False, False
# old => old  , True, False, False
# clothes => clothes  , True, False, False
# and => and  , True, False, True
# broken => broken  , True, False, False
# glasses => glasses , True, False, False
# , => ,  , False, True, False
# and => and  , True, False, True
# nobody => nobody , True, False, True
#
#  =>
#  , False, False, False
# liked => liked  , True, False, False
# to => to  , True, False, True
# disagree => disagree  , True, False, False
# with => with  , True, False, True
# Dudley => Dudley , True, False, False
# ’s => ’s  , False, False, True
# gang => gang , True, False, False
# . => . , False, True, False

# %% [markdown]
# Stop Words

# %%
list(spacy.lang.en.STOP_WORDS)[:10]
# Out:
# ['for',
#  'nine',
#  'why',
#  'used',
#  'same',
#  'either',
#  'eleven',
#  'much',
#  'fifty',
#  'cannot']

# %% [markdown]
# filtering tokens

# %%
[token.text for token in docs if not token.is_stop][:10]
# Out:
# ['VANISHING',
#  'GLASS',
#  '\n',
#  'N',
#  'early',
#  'years',
#  'passed',
#  'Dursleys',
#  'woken',
#  'find']

# %% [markdown]
# lemmatizaion

# %%
for token in docs:
    if str(token) != str(token.lemma_):
        print(token, token.lemma_)
# Out:
# THE the
# VANISHING vanish
# N n
# years year
# had have
# passed pass
# had have
# woken wake
# had have
# changed change
# The the
# rose rise
# gardens garden
# lit light
# ’ '
# crept creep
# was be
# had have
# been be
# had have
# seen see
# owls owl
# Only only
# photographs photograph
# showed show
# had have
# passed pass
# Ten ten
# years year
# had have
# been be
# lots lot
# pictures picture
# looked look
# wearing wear
# bonnets bonnet
# was be
# longer long
# photographs photograph
# showed show
# riding ride
# playing play
# being be
# hugged hug
# kissed kiss
# The the
# held hold
# lived live
# Yet yet
# was be
# His his
# was be
# was be
# made make
# “ "
# Up up
# Get get
# Now now
# ” "
# woke wake
# His his
# rapped rap
# “ "
# Up up
# ” "
# screeched screech
# heard hear
# her she
# walking walk
# frying fry
# being be
# He he
# rolled roll
# tried try
# had have
# been be
# having have
# It it
# had have
# been be
# There there
# had have
# been be
# flying fly
# He he
# had have
# had have
# His his
# was be
# “ "
# Are be
# ” "
# demanded demand
# “ "
# Nearly nearly
# ” "
# said say
# “ "
# Well well
# And and
# ” "
# groaned groan
# “ "
# What what
# did do
# ” "
# snapped snap
# “ "
# Nothing nothing
# ” "
# forgotten forget
# got get
# started start
# looking look
# socks sock
# He he
# found find
# pulling pull
# them they
# them they
# was be
# used use
# spiders spider
# stairs stair
# was be
# them they
# was be
# slept sleep
# When when
# was be
# dressed dress
# went go
# The the
# was be
# hidden hide
# presents present
# It it
# looked look
# had have
# gotten get
# wanted want
# racing race
# Exactly exactly
# wanted want
# was be
# was be
# hated hate
# involved involve
# punching punch
# was be
# n’t not
# him he
# did do
# n’t not
# was be
# Perhaps perhaps
# had have
# living live
# had have
# been be
# He he
# looked look
# smaller small
# skinnier skinny
# was be
# had have
# were be
# clothes clothe
# was be
# times time
# bigger big
# was be
# had have
# knees knee
# eyes eye
# He he
# wore wear
# glasses glass
# held hold
# times time
# had have
# punched punch
# him he
# The the
# liked like
# was be
# was be
# shaped shape
# He he
# had have
# had have
# asking ask
# was be
# had have
# gotten get
# “ "
# In in
# parents parent
# died die
# ” "
# had have
# said say
# “ "
# And and
# questions question
# ” "
# Do do
# n’t not
# questions question
# was be
# entered enter
# was be
# turning turn
# “ "
# Comb comb
# ” "
# barked bark
# About about
# looked look
# shouted shout
# needed need
# had have
# haircuts haircut
# boys boy
# made make
# grew grow
# was be
# frying fry
# eggs egg
# arrived arrive
# looked look
# He he
# had have
# eyes eye
# lay lie
# said say
# looked look
# said say
# looked look
# plates plate
# was be
# was be
# was be
# counting count
# presents present
# His his
# fell fall
# “ "
# Thirty thirty
# ” "
# said say
# looking look
# “ "
# That that
# ” "
# “ "
# Darling darling
# n’t not
# counted count
# ” "
# “ "
# All all
# ” "
# said say
# going go
# coming come
# began begin
# wolfing wolf
# turned turn
# said say
# “ "
# And and
# presents present
# How how
# Two two
# presents present
# Is be
# ” "
# thought think
# It it
# looked look
# Finally finally
# said say
# “ "
# So so
# ” "
# “ "
# Thirty thirty
# sweetums sweetum
# ” "
# said say
# “ "
# Oh oh
# ” "
# sat sit
# grabbed grab
# nearest near
# “ "
# All all
# ” "
# chuckled chuckle
# “ "
# Little little
# wants want
# ’ '
# Atta atta
# ” "
# He he
# ruffled ruffle
# At at
# went go
# watched watch
# racing race
# games game
# VCR vcr
# He he
# was be
# ripping rip
# came come
# looking look
# “ "
# Bad bad
# ” "
# said say
# “ "
# broken break
# She she
# ca can
# n’t not
# him he
# ” "
# She she
# jerked jerk
# fell fall
# gave give
# Every every
# parents parent
# took take
# him he
# parks park
# restaurants restaurant
# movies movie
# Every every
# was be
# left leave
# lived live
# streets street
# hated hate
# The the
# smelled smell
# made make
# him he
# photographs photograph
# cats cat
# owned own
# “ "
# Now now
# ” "
# said say
# looking look
# planned plan
# knew know
# had have
# broken break
# was be
# n’t not
# reminded remind
# had have
# “ "
# We we
# Marge marge
# ” "
# suggested suggest
# “ "
# Do do
# n’t not
# hates hate
# ” "
# The the
# spoke speak
# was be
# was be
# n’t not
# them they
# “ "
# What what
# her she
# ” "
# “ "
# On on
# ” "
# snapped snap
# “ "
# You you
# me I
# ” "
# wanted want
# looked look
# swallowed swallow
# “ "
# And and
# ruins ruin
# ” "
# snarled snarl
# “ "
# wo will
# n’t not
# ” "
# said say
# were be
# n’t not
# listening listen
# “ "
# him he
# ” "
# said say
# “ "
# him he
# ” "
# “ "
# That that
# ’s ’
# sitting sit
# ” "
# began begin
# In in
# was be
# n’t not
# crying cry
# had have
# been be
# years year
# cried cry
# knew know
# screwed screw
# wailed wail
# him he
# wanted want
# “ "
# wo will
# n’t not
# him he
# ” "
# cried cry
# flinging fling
# arms arm
# him he
# “ "
# him he
# ” "
# yelled yell
# sobs sob
# “ "
# He he
# spoils spoil
# ” "
# He he
# shot shoot
# arms arm
# Just just
# rang ring
# “ "
# Oh oh
# ” "
# said say
# best good
# walked walk
# Piers pier
# was be
# He he
# was be
# held hold
# arms arm
# backs back
# them they
# stopped stop
# pretending pretend
# Half half
# n’t not
# was be
# sitting sit
# ’ '
# His his
# had have
# n’t not
# been be
# him he
# left leave
# had have
# taken take
# “ "
# warning warn
# ” "
# had have
# said say
# putting put
# “ "
# warning warn
# ” "
# “ "
# going go
# ” "
# said say
# “ "
# ” "
# But but
# did do
# n’t not
# him he
# No no
# did do
# The the
# was be
# things thing
# happened happen
# was be
# telling tell
# Dursleys dursley
# did do
# n’t not
# them they
# Once once
# coming come
# barbers barber
# looking look
# had have
# n’t not
# been be
# had have
# taken take
# scissors scissor
# was be
# bangs bang
# left leave
# “ "
# ” "
# had have
# laughed laugh
# spent spend
# imagining imagine
# was be
# laughed laugh
# clothes clothe
# taped tape
# glasses glass
# Next next
# had have
# gotten get
# had have
# been be
# had have
# sheared shear
# He he
# had have
# been be
# given give
# had have
# tried try
# n’t not
# had have
# grown grow
# Another another
# had have
# been be
# trying try
# him he
# balls ball
# The the
# harder hard
# tried try
# smaller small
# seemed seem
# fitted fit
# n’t not
# had have
# decided decide
# shrunk shrink
# was be
# n’t not
# punished punish
# On on
# gotten get
# being be
# found find
# kitchens kitchen
# had have
# been be
# chasing chase
# him he
# was be
# sitting sit
# The the
# had have
# received receive
# telling tell
# them they
# had have
# been be
# climbing climb
# buildings building
# But but
# tried try
# shouted shout
# was be
# cans can
# doors door
# supposed suppose
# caught catch
# him he
# But but
# was be
# going go
# It it
# was be
# being be
# spending spend
# was be
# smelling smell
# While while
# drove drive
# complained complain
# He he
# liked like
# things thing
# were be
# subjects subject
# This this
# was be
# motorcycles motorcycle
# “ "
# roaring roar
# hoodlums hoodlum
# ” "
# said say
# overtook overtake
# them they
# “ "
# had have
# ” "
# said say
# remembering remember
# “ "
# It it
# was be
# flying fly
# ” "
# crashed crash
# He he
# turned turn
# yelled yell
# “ "
# ” "
# sniggered snigger
# “ "
# ” "
# said say
# “ "
# It it
# was be
# ” "
# But but
# wished wish
# had have
# said say
# If if
# was be
# hated hate
# asking ask
# questions question
# was be
# talking talk
# acting act
# was be
# seemed seem
# ideas idea
# It it
# was be
# was be
# crowded crowd
# families family
# The the
# bought buy
# creams cream
# smiling smile
# had have
# asked ask
# wanted want
# him he
# bought buy
# him he
# It it
# was be
# thought think
# licking lick
# watched watch
# scratching scratch
# looked look
# was be
# n’t not
# had have
# best good
# had have
# He he
# was be
# were be
# starting start
# bored bore
# animals animal
# n’t not
# hitting hit
# him he
# They they
# ate eat
# had have
# did do
# n’t not
# bought buy
# him he
# was be
# allowed allow
# felt feel
# known know
# was be
# After after
# went go
# It it
# was be
# lit light
# windows window
# walls wall
# Behind behind
# sorts sort
# lizards lizard
# snakes snake
# were be
# crawling crawl
# slithering slither
# bits bit
# wanted want
# cobras cobra
# crushing crush
# pythons python
# found find
# largest large
# It it
# wrapped wrap
# crushed crush
# did do
# n’t not
# In in
# was be
# stood stand
# pressed press
# staring stare
# glistening glisten
# coils coil
# “ "
# Make make
# ” "
# whined whine
# tapped tap
# did do
# “ "
# Do do
# ” "
# ordered order
# rapped rap
# knuckles knuckle
# snoozed snooze
# “ "
# This this
# is be
# ” "
# moaned moan
# He he
# shuffled shuffle
# moved move
# looked look
# He he
# n’t not
# been be
# had have
# died die
# drumming drum
# fingers finger
# trying try
# It it
# was be
# worse bad
# having have
# was be
# hammering hammer
# got get
# The the
# opened open
# eyes eye
# Slowly slowly
# raised raise
# eyes eye
# were be
# It it
# winked wink
# stared stare
# Then then
# looked look
# was be
# watching watch
# They they
# were be
# He he
# looked look
# winked wink
# The the
# jerked jerk
# raised raise
# eyes eye
# It it
# gave give
# said say
# “ "
# ” "
# “ "
# ” "
# murmured murmur
# was be
# n’t not
# him he
# “ "
# It it
# ” "
# The the
# nodded nod
# “ "
# Where where
# ” "
# asked ask
# The the
# jabbed jab
# peered peer
# “ "
# Was be
# ” "
# The the
# jabbed jab
# This this
# specimen speciman
# was be
# bred breed
# “ "
# Oh oh
# been be
# ” "
# As as
# shook shake
# made make
# them they
# “ "
# COME come
# AND and
# LOOK look
# AT at
# THIS this
# SNAKE snake
# YOU you
# WON’T won’t
# BELIEVE believe
# WHAT what
# DOING do
# ” "
# came come
# waddling waddle
# them they
# “ "
# Out out
# ” "
# said say
# punching punch
# ribs rib
# Caught catch
# fell fall
# What what
# came come
# happened happen
# saw see
# happened happen
# were be
# leaning lean
# had have
# howls howl
# sat sit
# gasped gasp
# had have
# vanished vanish
# The the
# was be
# uncoiling uncoil
# slithering slither
# screamed scream
# started start
# running run
# exits exit
# As as
# slid slide
# him he
# sworn swear
# hissing hiss
# said say
# “ "
# ” "
# The the
# was be
# “ "
# But but
# ” "
# kept keep
# saying say
# “ "
# did do
# ” "
# The the
# made make
# apologized apologize
# Piers pier
# As as
# had have
# seen see
# had have
# n’t not
# done do
# heels heel
# passed pass
# were be
# was be
# telling tell
# them they
# had have
# bitten bite
# Piers pier
# was be
# swearing swear
# had have
# tried try
# him he
# But but
# worst bad
# was be
# Piers pier
# calming calm
# “ "
# was be
# talking talk
# were be
# ” "
# waited wait
# was be
# starting start
# He he
# was be
# He he
# managed manage
# “ "
# Go go
# meals meal
# ” "
# collapsed collapse
# had have
# him he
# lay lie
# wishing wish
# had have
# He he
# did do
# was be
# n’t not
# were be
# Until until
# were be
# n’t not
# sneaking sneak
# He he
# lived live
# years year
# years year
# been be
# parents parent
# had have
# died die
# He he
# n’t not
# being be
# parents parent
# had have
# died die
# Sometimes sometimes
# strained strain
# hours hour
# came come
# blinding blind
# burning burn
# This this
# supposed suppose
# was be
# n’t not
# came come
# He he
# n’t not
# parents parent
# His his
# spoke speak
# them they
# was be
# forbidden forbid
# questions question
# There there
# were be
# photographs photograph
# them they
# When when
# had have
# been be
# younger young
# had have
# dreamed dream
# dreamed dream
# coming come
# him he
# had have
# happened happen
# were be
# Yet yet
# thought think
# hoped hope
# strangers stranger
# seemed seem
# him he
# Very very
# strangers stranger
# were be
# A a
# had have
# bowed bow
# him he
# shopping shop
# After after
# asking ask
# knew know
# had have
# rushed rush
# them they
# buying buy
# A a
# looking look
# dressed dress
# had have
# waved wave
# him he
# A a
# had have
# shaken shake
# walked walk
# The the
# weirdest weird
# was be
# seemed seem
# tried try
# closer close
# At at
# had have
# Everybody everybody
# knew know
# hated hate
# clothes clothe
# glasses glass
# liked like

# %% [markdown]
# Word Frequency

# %%
from collections import Counter

words = [token.text for token in docs if not token.is_stop and not token.is_punct  ]
frq = Counter(words).most_common(10)
frq
# Out:
# [('\n', 294),
#  ('Harry', 79),
#  ('Dudley', 54),
#  ('said', 23),
#  ('Aunt', 22),
#  ('Petunia', 22),
#  ('Vernon', 20),
#  ('Uncle', 18),
#  ('snake', 14),
#  ('Dursleys', 13)]

# %% [markdown]
# Part-of-Speech

# %%
[(token.text, token.tag_, spacy.explain(token.tag_)) for token in docs if not token.is_stop and not token.is_punct  ]
# Out:
# [('VANISHING', 'VBG', 'verb, gerund or present participle'),
#  ('GLASS', 'NNP', 'noun, proper singular'),
#  ('\n', '_SP', 'whitespace'),
#  ('N', 'CD', 'cardinal number'),
#  ('early', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('years', 'NNS', 'noun, plural'),
#  ('passed', 'VBN', 'verb, past participle'),
#  ('Dursleys', 'NNPS', 'noun, proper plural'),
#  ('woken', 'VBN', 'verb, past participle'),
#  ('find', 'VB', 'verb, base form'),
#  ('\n', '_SP', 'whitespace'),
#  ('nephew', 'NN', 'noun, singular or mass'),
#  ('step', 'NN', 'noun, singular or mass'),
#  ('Privet', 'NNP', 'noun, proper singular'),
#  ('Drive', 'NNP', 'noun, proper singular'),
#  ('hardly', 'RB', 'adverb'),
#  ('changed', 'VBN', 'verb, past participle'),
#  ('sun', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('rose', 'VBD', 'verb, past tense'),
#  ('tidy', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('gardens', 'NNS', 'noun, plural'),
#  ('lit', 'VBD', 'verb, past tense'),
#  ('brass', 'NN', 'noun, singular or mass'),
#  ('number', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('Dursleys', 'NNP', 'noun, proper singular'),
#  ('door', 'NN', 'noun, singular or mass'),
#  ('crept', 'VBD', 'verb, past tense'),
#  ('living', 'NN', 'noun, singular or mass'),
#  ('room', 'NN', 'noun, singular or mass'),
#  ('exactly', 'RB', 'adverb'),
#  ('\n', '_SP', 'whitespace'),
#  ('night', 'NN', 'noun, singular or mass'),
#  ('Mr.', 'NNP', 'noun, proper singular'),
#  ('Dursley', 'NNP', 'noun, proper singular'),
#  ('seen', 'VBN', 'verb, past participle'),
#  ('fateful', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('news', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('report', 'NN', 'noun, singular or mass'),
#  ('owls', 'NNS', 'noun, plural'),
#  ('photographs', 'NNS', 'noun, plural'),
#  ('mantelpiece', 'NN', 'noun, singular or mass'),
#  ('showed', 'VBD', 'verb, past tense'),
#  ('\n', '_SP', 'whitespace'),
#  ('time', 'NN', 'noun, singular or mass'),
#  ('passed', 'VBN', 'verb, past participle'),
#  ('years', 'NNS', 'noun, plural'),
#  ('ago', 'RB', 'adverb'),
#  ('lots', 'NNS', 'noun, plural'),
#  ('pictures', 'NNS', 'noun, plural'),
#  ('\n', '_SP', 'whitespace'),
#  ('looked', 'VBD', 'verb, past tense'),
#  ('like', 'IN', 'conjunction, subordinating or preposition'),
#  ('large', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('pink', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('beach', 'NN', 'noun, singular or mass'),
#  ('ball', 'NN', 'noun, singular or mass'),
#  ('wearing', 'VBG', 'verb, gerund or present participle'),
#  ('different', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('colored', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('bonnets', 'NNS', 'noun, plural'),
#  ('\n', '_SP', 'whitespace'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('Dursley', 'NNP', 'noun, proper singular'),
#  ('longer', 'RBR', 'adverb, comparative'),
#  ('baby', 'NN', 'noun, singular or mass'),
#  ('photographs', 'NNS', 'noun, plural'),
#  ('showed', 'VBD', 'verb, past tense'),
#  ('\n', '_SP', 'whitespace'),
#  ('large', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('blond', 'NN', 'noun, singular or mass'),
#  ('boy', 'NN', 'noun, singular or mass'),
#  ('riding', 'VBG', 'verb, gerund or present participle'),
#  ('bicycle', 'NN', 'noun, singular or mass'),
#  ('carousel', 'NN', 'noun, singular or mass'),
#  ('fair', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('playing', 'VBG', 'verb, gerund or present participle'),
#  ('\n', '_SP', 'whitespace'),
#  ('computer', 'NN', 'noun, singular or mass'),
#  ('game', 'NN', 'noun, singular or mass'),
#  ('father', 'NN', 'noun, singular or mass'),
#  ('hugged', 'VBN', 'verb, past participle'),
#  ('kissed', 'VBN', 'verb, past participle'),
#  ('mother', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('room', 'NN', 'noun, singular or mass'),
#  ('held', 'VBD', 'verb, past tense'),
#  ('sign', 'NN', 'noun, singular or mass'),
#  ('boy', 'NN', 'noun, singular or mass'),
#  ('lived', 'VBD', 'verb, past tense'),
#  ('house', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('Potter', 'NNP', 'noun, proper singular'),
#  ('asleep', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('moment', 'NN', 'noun, singular or mass'),
#  ('long', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('\n', '_SP', 'whitespace'),
#  ('Aunt', 'NNP', 'noun, proper singular'),
#  ('Petunia', 'NNP', 'noun, proper singular'),
#  ('awake', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('shrill', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('voice', 'NN', 'noun, singular or mass'),
#  ('noise', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('day', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('\n', '_SP', 'whitespace'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('woke', 'VBD', 'verb, past tense'),
#  ('start', 'NN', 'noun, singular or mass'),
#  ('aunt', 'NN', 'noun, singular or mass'),
#  ('rapped', 'VBD', 'verb, past tense'),
#  ('door', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('screeched', 'VBD', 'verb, past tense'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('heard', 'VBD', 'verb, past tense'),
#  ('walking', 'VBG', 'verb, gerund or present participle'),
#  ('kitchen', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('sound', 'NN', 'noun, singular or mass'),
#  ('frying', 'VBG', 'verb, gerund or present participle'),
#  ('pan', 'NN', 'noun, singular or mass'),
#  ('stove', 'NN', 'noun, singular or mass'),
#  ('rolled', 'VBD', 'verb, past tense'),
#  ('\n', '_SP', 'whitespace'),
#  ('tried', 'VBD', 'verb, past tense'),
#  ('remember', 'VB', 'verb, base form'),
#  ('dream', 'NN', 'noun, singular or mass'),
#  ('having', 'VBG', 'verb, gerund or present participle'),
#  ('good', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('\n', '_SP', 'whitespace'),
#  ('flying', 'VBG', 'verb, gerund or present participle'),
#  ('motorcycle', 'NN', 'noun, singular or mass'),
#  ('funny', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('feeling', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('dream', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('aunt', 'NN', 'noun, singular or mass'),
#  ('outside', 'IN', 'conjunction, subordinating or preposition'),
#  ('door', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('demanded', 'VBD', 'verb, past tense'),
#  ('\n', '_SP', 'whitespace'),
#  ('Nearly', 'RB', 'adverb'),
#  ('said', 'VBD', 'verb, past tense'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('\n', '_SP', 'whitespace'),
#  ('want', 'VBP', 'verb, non-3rd person singular present'),
#  ('look', 'VB', 'verb, base form'),
#  ('bacon', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('dare', 'VB', 'verb, base form'),
#  ('let', 'VB', 'verb, base form'),
#  ('burn', 'VB', 'verb, base form'),
#  ('want', 'VBP', 'verb, non-3rd person singular present'),
#  ('perfect', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('Duddy', 'NNP', 'noun, proper singular'),
#  ('birthday', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('groaned', 'VBD', 'verb, past tense'),
#  ('\n', '_SP', 'whitespace'),
#  ('aunt', 'NN', 'noun, singular or mass'),
#  ('snapped', 'VBD', 'verb, past tense'),
#  ('door', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('\n', '_SP', 'whitespace'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('birthday', 'NN', 'noun, singular or mass'),
#  ('forgotten', 'VBN', 'verb, past participle'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('got', 'VBD', 'verb, past tense'),
#  ('slowly', 'RB', 'adverb'),
#  ('\n', '_SP', 'whitespace'),
#  ('bed', 'NN', 'noun, singular or mass'),
#  ('started', 'VBD', 'verb, past tense'),
#  ('looking', 'VBG', 'verb, gerund or present participle'),
#  ('socks', 'NNS', 'noun, plural'),
#  ('found', 'VBD', 'verb, past tense'),
#  ('pair', 'NN', 'noun, singular or mass'),
#  ('bed', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('pulling', 'VBG', 'verb, gerund or present participle'),
#  ('spider', 'NN', 'noun, singular or mass'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('spiders', 'NNS', 'noun, plural'),
#  ('\n', '_SP', 'whitespace'),
#  ('cupboard', 'NN', 'noun, singular or mass'),
#  ('stairs', 'NNS', 'noun, plural'),
#  ('slept', 'VBD', 'verb, past tense'),
#  ('\n', '_SP', 'whitespace'),
#  ('dressed', 'VBN', 'verb, past participle'),
#  ('went', 'VBD', 'verb, past tense'),
#  ('hall', 'NN', 'noun, singular or mass'),
#  ('kitchen', 'NN', 'noun, singular or mass'),
#  ('table', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('hidden', 'VBN', 'verb, past participle'),
#  ('beneath', 'IN', 'conjunction, subordinating or preposition'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('birthday', 'NN', 'noun, singular or mass'),
#  ('presents', 'VBZ', 'verb, 3rd person singular present'),
#  ('looked', 'VBD', 'verb, past tense'),
#  ('\n', '_SP', 'whitespace'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('gotten', 'VBN', 'verb, past participle'),
#  ('new', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('computer', 'NN', 'noun, singular or mass'),
#  ('wanted', 'VBD', 'verb, past tense'),
#  ('mention', 'VB', 'verb, base form'),
#  ('second', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('\n', '_SP', 'whitespace'),
#  ('television', 'NN', 'noun, singular or mass'),
#  ('racing', 'VBG', 'verb, gerund or present participle'),
#  ('bike', 'NN', 'noun, singular or mass'),
#  ('Exactly', 'RB', 'adverb'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('wanted', 'VBD', 'verb, past tense'),
#  ('racing', 'NN', 'noun, singular or mass'),
#  ('bike', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('mystery', 'NN', 'noun, singular or mass'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('fat', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('hated', 'VBN', 'verb, past participle'),
#  ('exercise', 'NN', 'noun, singular or mass'),
#  ('course', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('involved', 'VBD', 'verb, past tense'),
#  ('punching', 'VBG', 'verb, gerund or present participle'),
#  ('somebody', 'NN', 'noun, singular or mass'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('favorite', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('punching', 'NN', 'noun, singular or mass'),
#  ('bag', 'NN', 'noun, singular or mass'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('\n', '_SP', 'whitespace'),
#  ('catch', 'VB', 'verb, base form'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('look', 'VB', 'verb, base form'),
#  ('fast', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('\n', '_SP', 'whitespace'),
#  ('living', 'VBG', 'verb, gerund or present participle'),
#  ('dark', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('cupboard', 'NN', 'noun, singular or mass'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('\n', '_SP', 'whitespace'),
#  ('small', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('skinny', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('age', 'NN', 'noun, singular or mass'),
#  ('looked', 'VBD', 'verb, past tense'),
#  ('smaller', 'JJR', 'adjective, comparative'),
#  ('\n', '_SP', 'whitespace'),
#  ('skinnier', 'JJR', 'adjective, comparative'),
#  ('wear', 'VB', 'verb, base form'),
#  ('old', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('clothes', 'NNS', 'noun, plural'),
#  ('\n', '_SP', 'whitespace'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('times', 'NNS', 'noun, plural'),
#  ('bigger', 'JJR', 'adjective, comparative'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('thin', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('\n', '_SP', 'whitespace'),
#  ('face', 'NN', 'noun, singular or mass'),
#  ('knobbly', 'RB', 'adverb'),
#  ('knees', 'NNS', 'noun, plural'),
#  ('black', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('hair', 'NN', 'noun, singular or mass'),
#  ('bright', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('green', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('eyes', 'NNS', 'noun, plural'),
#  ('wore', 'VBD', 'verb, past tense'),
#  ('round', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('glasses', 'NNS', 'noun, plural'),
#  ('\n', '_SP', 'whitespace'),
#  ('held', 'VBN', 'verb, past participle'),
#  ('lot', 'NN', 'noun, singular or mass'),
#  ('Scotch', 'NNP', 'noun, proper singular'),
#  ('tape', 'NN', 'noun, singular or mass'),
#  ('times', 'NNS', 'noun, plural'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('\n', '_SP', 'whitespace'),
#  ('punched', 'VBN', 'verb, past participle'),
#  ('nose', 'NN', 'noun, singular or mass'),
#  ('thing', 'NN', 'noun, singular or mass'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('liked', 'VBD', 'verb, past tense'),
#  ('appearance', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('thin', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('scar', 'NN', 'noun, singular or mass'),
#  ('forehead', 'NN', 'noun, singular or mass'),
#  ('shaped', 'VBN', 'verb, past participle'),
#  ('like', 'IN', 'conjunction, subordinating or preposition'),
#  ('bolt', 'NN', 'noun, singular or mass'),
#  ('lightning', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('long', 'RB', 'adverb'),
#  ('remember', 'VB', 'verb, base form'),
#  ('question', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('remember', 'VB', 'verb, base form'),
#  ('asking', 'VBG', 'verb, gerund or present participle'),
#  ('Aunt', 'NNP', 'noun, proper singular'),
#  ('Petunia', 'NNP', 'noun, proper singular'),
#  ('gotten', 'VBN', 'verb, past participle'),
#  ('\n', '_SP', 'whitespace'),
#  ('car', 'NN', 'noun, singular or mass'),
#  ('crash', 'NN', 'noun, singular or mass'),
#  ('parents', 'NNS', 'noun, plural'),
#  ('died', 'VBD', 'verb, past tense'),
#  ('said', 'VBN', 'verb, past participle'),
#  ('ask', 'VB', 'verb, base form'),
#  ('\n', '_SP', 'whitespace'),
#  ('questions', 'NNS', 'noun, plural'),
#  ('\n', '_SP', 'whitespace'),
#  ('ask', 'VB', 'verb, base form'),
#  ('questions', 'NNS', 'noun, plural'),
#  ('rule', 'NN', 'noun, singular or mass'),
#  ('quiet', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('life', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('Dursleys', 'NNP', 'noun, proper singular'),
#  ('\n', '_SP', 'whitespace'),
#  ('Uncle', 'NNP', 'noun, proper singular'),
#  ('Vernon', 'NNP', 'noun, proper singular'),
#  ('entered', 'VBD', 'verb, past tense'),
#  ('kitchen', 'NN', 'noun, singular or mass'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('turning', 'VBG', 'verb, gerund or present participle'),
#  ('bacon', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('Comb', 'VB', 'verb, base form'),
#  ('hair', 'NN', 'noun, singular or mass'),
#  ('barked', 'VBD', 'verb, past tense'),
#  ('way', 'NN', 'noun, singular or mass'),
#  ('morning', 'NN', 'noun, singular or mass'),
#  ('greeting', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('week', 'NN', 'noun, singular or mass'),
#  ('Uncle', 'NNP', 'noun, proper singular'),
#  ('Vernon', 'NNP', 'noun, proper singular'),
#  ('looked', 'VBD', 'verb, past tense'),
#  ('newspaper', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('shouted', 'VBD', 'verb, past tense'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('needed', 'VBD', 'verb, past tense'),
#  ('haircut', 'NN', 'noun, singular or mass'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('haircuts', 'NNS', 'noun, plural'),
#  ('\n', '_SP', 'whitespace'),
#  ('rest', 'NN', 'noun, singular or mass'),
#  ('boys', 'NNS', 'noun, plural'),
#  ('class', 'NN', 'noun, singular or mass'),
#  ('difference', 'NN', 'noun, singular or mass'),
#  ('hair', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('simply', 'RB', 'adverb'),
#  ('grew', 'VBD', 'verb, past tense'),
#  ('way', 'NN', 'noun, singular or mass'),
#  ('place', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('frying', 'VBG', 'verb, gerund or present participle'),
#  ('eggs', 'NNS', 'noun, plural'),
#  ('time', 'NN', 'noun, singular or mass'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('arrived', 'VBD', 'verb, past tense'),
#  ('kitchen', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('mother', 'NN', 'noun, singular or mass'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('looked', 'VBD', 'verb, past tense'),
#  ('lot', 'NN', 'noun, singular or mass'),
#  ('like', 'IN', 'conjunction, subordinating or preposition'),
#  ('Uncle', 'NNP', 'noun, proper singular'),
#  ('Vernon', 'NNP', 'noun, proper singular'),
#  ('large', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('pink', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('face', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('neck', 'NN', 'noun, singular or mass'),
#  ('small', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('watery', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('blue', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('eyes', 'NNS', 'noun, plural'),
#  ('thick', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('blond', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('hair', 'NN', 'noun, singular or mass'),
#  ('lay', 'VBD', 'verb, past tense'),
#  ('smoothly', 'RB', 'adverb'),
#  ('\n', '_SP', 'whitespace'),
#  ('thick', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('fat', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('head', 'NN', 'noun, singular or mass'),
#  ('Aunt', 'NNP', 'noun, proper singular'),
#  ('Petunia', 'NNP', 'noun, proper singular'),
#  ('said', 'VBD', 'verb, past tense'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('looked', 'VBD', 'verb, past tense'),
#  ('like', 'IN', 'conjunction, subordinating or preposition'),
#  ('baby', 'NN', 'noun, singular or mass'),
#  ('angel', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('said', 'VBD', 'verb, past tense'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('looked', 'VBD', 'verb, past tense'),
#  ('like', 'IN', 'conjunction, subordinating or preposition'),
#  ('pig', 'NN', 'noun, singular or mass'),
#  ('wig', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('plates', 'NNS', 'noun, plural'),
#  ('egg', 'NN', 'noun, singular or mass'),
#  ('bacon', 'NN', 'noun, singular or mass'),
#  ('table', 'NN', 'noun, singular or mass'),
#  ('difficult', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('\n', '_SP', 'whitespace'),
#  ('room', 'NN', 'noun, singular or mass'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('counting', 'VBG', 'verb, gerund or present participle'),
#  ('presents', 'NNS', 'noun, plural'),
#  ('\n', '_SP', 'whitespace'),
#  ('face', 'NN', 'noun, singular or mass'),
#  ('fell', 'VBD', 'verb, past tense'),
#  ('\n', '_SP', 'whitespace'),
#  ('Thirty', 'CD', 'cardinal number'),
#  ('said', 'VBD', 'verb, past tense'),
#  ('looking', 'VBG', 'verb, gerund or present participle'),
#  ('mother', 'NN', 'noun, singular or mass'),
#  ('father', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('year', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('Darling', 'NN', 'noun, singular or mass'),
#  ('counted', 'VBN', 'verb, past participle'),
#  ('Auntie', 'NNP', 'noun, proper singular'),
#  ('Marge', 'NNP', 'noun, proper singular'),
#  ('present', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('\n', '_SP', 'whitespace'),
#  ('big', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('Mummy', 'NNP', 'noun, proper singular'),
#  ('Daddy', 'NNP', 'noun, proper singular'),
#  ('\n', '_SP', 'whitespace'),
#  ('right', 'RB', 'adverb'),
#  ('thirty', 'CD', 'cardinal number'),
#  ('seven', 'CD', 'cardinal number'),
#  ('said', 'VBD', 'verb, past tense'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('going', 'VBG', 'verb, gerund or present participle'),
#  ('red', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('face', 'NN', 'noun, singular or mass'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('\n', '_SP', 'whitespace'),
#  ('huge', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('tantrum', 'NN', 'noun, singular or mass'),
#  ('coming', 'VBG', 'verb, gerund or present participle'),
#  ('began', 'VBD', 'verb, past tense'),
#  ('wolfing', 'VBG', 'verb, gerund or present participle'),
#  ('bacon', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('fast', 'RB', 'adverb'),
#  ('possible', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('case', 'NN', 'noun, singular or mass'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('turned', 'VBD', 'verb, past tense'),
#  ('table', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('Aunt', 'NNP', 'noun, proper singular'),
#  ('Petunia', 'NNP', 'noun, proper singular'),
#  ('obviously', 'RB', 'adverb'),
#  ('scented', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('danger', 'NN', 'noun, singular or mass'),
#  ('said', 'VBD', 'verb, past tense'),
#  ('quickly', 'RB', 'adverb'),
#  ('\n', '_SP', 'whitespace'),
#  ('buy', 'VB', 'verb, base form'),
#  ('presents', 'NNS', 'noun, plural'),
#  ('today', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('popkin', 'NN', 'noun, singular or mass'),
#  ('presents', 'NNS', 'noun, plural'),
#  ('right', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('\n', '_SP', 'whitespace'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('thought', 'VBD', 'verb, past tense'),
#  ('moment', 'NN', 'noun, singular or mass'),
#  ('looked', 'VBD', 'verb, past tense'),
#  ('like', 'IN', 'conjunction, subordinating or preposition'),
#  ('hard', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('work', 'NN', 'noun, singular or mass'),
#  ('Finally', 'RB', 'adverb'),
#  ('said', 'VBD', 'verb, past tense'),
#  ('\n', '_SP', 'whitespace'),
#  ('slowly', 'RB', 'adverb'),
#  ('thirty', 'CD', 'cardinal number'),
#  ('thirty', 'CD', 'cardinal number'),
#  ('\n', '_SP', 'whitespace'),
#  ('Thirty', 'CD', 'cardinal number'),
#  ('sweetums', 'NNS', 'noun, plural'),
#  ('said', 'VBD', 'verb, past tense'),
#  ('Aunt', 'NNP', 'noun, proper singular'),
#  ('Petunia', 'NNP', 'noun, proper singular'),
#  ('\n', '_SP', 'whitespace'),
#  ('Oh', 'UH', 'interjection'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('sat', 'VBD', 'verb, past tense'),
#  ('heavily', 'RB', 'adverb'),
#  ('grabbed', 'VBD', 'verb, past tense'),
#  ('nearest', 'JJS', 'adjective, superlative'),
#  ('parcel', 'NN', 'noun, singular or mass'),
#  ('right', 'RB', 'adverb'),
#  ('\n', '_SP', 'whitespace'),
#  ('\n', '_SP', 'whitespace'),
#  ('Uncle', 'NNP', 'noun, proper singular'),
#  ('Vernon', 'NNP', 'noun, proper singular'),
#  ('chuckled', 'VBD', 'verb, past tense'),
#  ('\n', '_SP', 'whitespace'),
#  ('Little', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('tyke', 'NN', 'noun, singular or mass'),
#  ('wants', 'VBZ', 'verb, 3rd person singular present'),
#  ('money', 'NN', 'noun, singular or mass'),
#  ('worth', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('like', 'IN', 'conjunction, subordinating or preposition'),
#  ('father', 'NN', 'noun, singular or mass'),
#  ('Atta', 'NN', 'noun, singular or mass'),
#  ('boy', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('ruffled', 'VBD', 'verb, past tense'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('hair', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('moment', 'NN', 'noun, singular or mass'),
#  ('telephone', 'NN', 'noun, singular or mass'),
#  ('rang', 'NN', 'noun, singular or mass'),
#  ('Aunt', 'NNP', 'noun, proper singular'),
#  ('Petunia', 'NNP', 'noun, proper singular'),
#  ('went', 'VBD', 'verb, past tense'),
#  ('answer', 'VB', 'verb, base form'),
#  ('\n', '_SP', 'whitespace'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('Uncle', 'NNP', 'noun, proper singular'),
#  ('Vernon', 'NNP', 'noun, proper singular'),
#  ('watched', 'VBD', 'verb, past tense'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('unwrap', 'NN', 'noun, singular or mass'),
#  ('racing', 'VBG', 'verb, gerund or present participle'),
#  ('bike', 'NN', 'noun, singular or mass'),
#  ('video', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('camera', 'NN', 'noun, singular or mass'),
#  ('remote', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('control', 'NN', 'noun, singular or mass'),
#  ('airplane', 'NN', 'noun, singular or mass'),
#  ('sixteen', 'CD', 'cardinal number'),
#  ('new', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('computer', 'NN', 'noun, singular or mass'),
#  ('games', 'NNS', 'noun, plural'),
#  ('VCR', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('ripping', 'VBG', 'verb, gerund or present participle'),
#  ('paper', 'NN', 'noun, singular or mass'),
#  ('gold', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('wristwatch', 'NN', 'noun, singular or mass'),
#  ('Aunt', 'NNP', 'noun, proper singular'),
#  ('Petunia', 'NNP', 'noun, proper singular'),
#  ('came', 'VBD', 'verb, past tense'),
#  ('\n', '_SP', 'whitespace'),
#  ('telephone', 'NN', 'noun, singular or mass'),
#  ('looking', 'VBG', 'verb, gerund or present participle'),
#  ('angry', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('worried', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('\n', '_SP', 'whitespace'),
#  ('Bad', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('news', 'NN', 'noun, singular or mass'),
#  ('Vernon', 'NNP', 'noun, proper singular'),
#  ('said', 'VBD', 'verb, past tense'),
#  ('Mrs.', 'NNP', 'noun, proper singular'),
#  ('Figg', 'NNP', 'noun, proper singular'),
#  ('broken', 'VBD', 'verb, past tense'),
#  ('leg', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('jerked', 'VBD', 'verb, past tense'),
#  ('head', 'NN', 'noun, singular or mass'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('direction', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('mouth', 'NN', 'noun, singular or mass'),
#  ('fell', 'VBD', 'verb, past tense'),
#  ('open', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('horror', 'NN', 'noun, singular or mass'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('heart', 'NN', 'noun, singular or mass'),
#  ('gave', 'VBD', 'verb, past tense'),
#  ('leap', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('year', 'NN', 'noun, singular or mass'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('birthday', 'NN', 'noun, singular or mass'),
#  ('parents', 'NNS', 'noun, plural'),
#  ('took', 'VBD', 'verb, past tense'),
#  ('friend', 'NN', 'noun, singular or mass'),
#  ('day', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('adventure', 'VB', 'verb, base form'),
#  ('parks', 'NNS', 'noun, plural'),
#  ('hamburger', 'NN', 'noun, singular or mass'),
#  ('restaurants', 'NNS', 'noun, plural'),
#  ('movies', 'NNS', 'noun, plural'),
#  ('year', 'NN', 'noun, singular or mass'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('\n', '_SP', 'whitespace'),
#  ('left', 'VBN', 'verb, past participle'),
#  ('Mrs.', 'NNP', 'noun, proper singular'),
#  ('Figg', 'NNP', 'noun, proper singular'),
#  ('mad', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('old', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('lady', 'NN', 'noun, singular or mass'),
#  ('lived', 'VBD', 'verb, past tense'),
#  ('streets', 'NNS', 'noun, plural'),
#  ('away', 'RB', 'adverb'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('\n', '_SP', 'whitespace'),
#  ('hated', 'VBD', 'verb, past tense'),
#  ('house', 'NN', 'noun, singular or mass'),
#  ('smelled', 'VBN', 'verb, past participle'),
#  ('cabbage', 'NN', 'noun, singular or mass'),
#  ('Mrs.', 'NNP', 'noun, proper singular'),
#  ('Figg', 'NNP', 'noun, proper singular'),
#  ('\n', '_SP', 'whitespace'),
#  ('look', 'VB', 'verb, base form'),
#  ('photographs', 'NNS', 'noun, plural'),
#  ('cats', 'NNS', 'noun, plural'),
#  ('owned', 'VBN', 'verb, past participle'),
#  ('\n', '_SP', 'whitespace'),
#  ('said', 'VBD', 'verb, past tense'),
#  ('Aunt', 'NNP', 'noun, proper singular'),
#  ('Petunia', 'NNP', 'noun, proper singular'),
#  ('looking', 'VBG', 'verb, gerund or present participle'),
#  ('furiously', 'RB', 'adverb'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('\n', '_SP', 'whitespace'),
#  ('planned', 'VBD', 'verb, past tense'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('knew', 'VBD', 'verb, past tense'),
#  ('ought', 'MD', 'verb, modal auxiliary'),
#  ('feel', 'VB', 'verb, base form'),
#  ('sorry', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('Mrs.', 'NNP', 'noun, proper singular'),
#  ('Figg', 'NNP', 'noun, proper singular'),
#  ('broken', 'VBN', 'verb, past participle'),
#  ('\n', '_SP', 'whitespace'),
#  ('leg', 'NN', 'noun, singular or mass'),
#  ('easy', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('reminded', 'VBD', 'verb, past tense'),
#  ('year', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('look', 'VB', 'verb, base form'),
#  ('Tibbles', 'NNP', 'noun, proper singular'),
#  ('Snowy', 'NNP', 'noun, proper singular'),
#  ('Mr.', 'NNP', 'noun, proper singular'),
#  ('Paws', 'NNP', 'noun, proper singular'),
#  ('Tufty', 'NNP', 'noun, proper singular'),
#  ('\n', '_SP', 'whitespace'),
#  ('phone', 'VB', 'verb, base form'),
#  ('Marge', 'NN', 'noun, singular or mass'),
#  ('Uncle', 'NNP', 'noun, proper singular'),
#  ('Vernon', 'NNP', 'noun, proper singular'),
#  ('suggested', 'VBD', 'verb, past tense'),
#  ('\n', '_SP', 'whitespace'),
#  ('silly', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('Vernon', 'NNP', 'noun, proper singular'),
#  ('hates', 'VBZ', 'verb, 3rd person singular present'),
#  ('boy', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('Dursleys', 'NNPS', 'noun, proper plural'),
#  ('spoke', 'VBD', 'verb, past tense'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('like', 'IN', 'conjunction, subordinating or preposition'),
#  ('\n', '_SP', 'whitespace'),
#  ('nasty', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('understand', 'VB', 'verb, base form'),
#  ('\n', '_SP', 'whitespace'),
#  ('like', 'IN', 'conjunction, subordinating or preposition'),
#  ('slug', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('what’s', 'NN', 'noun, singular or mass'),
#  ('friend', 'NN', 'noun, singular or mass'),
#  ('Yvonne', 'NNP', 'noun, proper singular'),
#  ('\n', '_SP', 'whitespace'),
#  ('vacation', 'NN', 'noun, singular or mass'),
#  ('Majorca', 'NNP', 'noun, proper singular'),
#  ('snapped', 'VBD', 'verb, past tense'),
#  ('Aunt', 'NNP', 'noun, proper singular'),
#  ('Petunia', 'NNP', 'noun, proper singular'),
#  ('\n', '_SP', 'whitespace'),
#  ('leave', 'VB', 'verb, base form'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('hopefully', 'RB', 'adverb'),
#  ('able', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('\n', '_SP', 'whitespace'),
#  ('watch', 'VB', 'verb, base form'),
#  ('wanted', 'VBD', 'verb, past tense'),
#  ('television', 'NN', 'noun, singular or mass'),
#  ('change', 'NN', 'noun, singular or mass'),
#  ('maybe', 'RB', 'adverb'),
#  ('\n', '_SP', 'whitespace'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('computer', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('Aunt', 'NNP', 'noun, proper singular'),
#  ('Petunia', 'NNP', 'noun, proper singular'),
#  ('looked', 'VBD', 'verb, past tense'),
#  ('swallowed', 'VBD', 'verb, past tense'),
#  ('lemon', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('come', 'VB', 'verb, base form'),
#  ('find', 'VB', 'verb, base form'),
#  ('house', 'NN', 'noun, singular or mass'),
#  ('ruins', 'NNS', 'noun, plural'),
#  ('snarled', 'VBD', 'verb, past tense'),
#  ('\n', '_SP', 'whitespace'),
#  ('wo', 'MD', 'verb, modal auxiliary'),
#  ('blow', 'VB', 'verb, base form'),
#  ('house', 'NN', 'noun, singular or mass'),
#  ('said', 'VBD', 'verb, past tense'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('listening', 'VBG', 'verb, gerund or present participle'),
#  ('\n', '_SP', 'whitespace'),
#  ('suppose', 'VBP', 'verb, non-3rd person singular present'),
#  ('zoo', 'NN', 'noun, singular or mass'),
#  ('said', 'VBD', 'verb, past tense'),
#  ('Aunt', 'NNP', 'noun, proper singular'),
#  ('Petunia', 'NNP', 'noun, proper singular'),
#  ('slowly', 'RB', 'adverb'),
#  ('\n', '_SP', 'whitespace'),
#  ('leave', 'VB', 'verb, base form'),
#  ('car', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('car', 'NN', 'noun, singular or mass'),
#  ('new', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('sitting', 'VBG', 'verb, gerund or present participle'),
#  ('\n', '_SP', 'whitespace'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('began', 'VBD', 'verb, past tense'),
#  ('cry', 'VB', 'verb, base form'),
#  ('loudly', 'RB', 'adverb'),
#  ('fact', 'NN', 'noun, singular or mass'),
#  ('crying', 'VBG', 'verb, gerund or present participle'),
#  ('\n', '_SP', 'whitespace'),
#  ('years', 'NNS', 'noun, plural'),
#  ('cried', 'VBD', 'verb, past tense'),
#  ('knew', 'VBD', 'verb, past tense'),
#  ('screwed', 'VBD', 'verb, past tense'),
#  ('face', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('wailed', 'VBD', 'verb, past tense'),
#  ('mother', 'NN', 'noun, singular or mass'),
#  ('wanted', 'VBD', 'verb, past tense'),
#  ('\n', '_SP', 'whitespace'),
#  ('Dinky', 'NNP', 'noun, proper singular'),
#  ('Duddydums', 'NNP', 'noun, proper singular'),
#  ('cry', 'VB', 'verb, base form'),
#  ('Mummy', 'NNP', 'noun, proper singular'),
#  ('wo', 'MD', 'verb, modal auxiliary'),
#  ('let', 'VB', 'verb, base form'),
#  ('spoil', 'VB', 'verb, base form'),
#  ('special', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('\n', '_SP', 'whitespace'),
#  ('day', 'NN', 'noun, singular or mass'),
#  ('cried', 'VBD', 'verb, past tense'),
#  ('flinging', 'VBG', 'verb, gerund or present participle'),
#  ('arms', 'NNS', 'noun, plural'),
#  ('\n', '_SP', 'whitespace'),
#  ('don’t', 'CD', 'cardinal number'),
#  ('want', 'NN', 'noun, singular or mass'),
#  ('t', 'NN', 'noun, singular or mass'),
#  ('t', 'NN', 'noun, singular or mass'),
#  ('come', 'VB', 'verb, base form'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('yelled', 'VBD', 'verb, past tense'),
#  ('huge', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('\n', '_SP', 'whitespace'),
#  ('pretend', 'NN', 'noun, singular or mass'),
#  ('sobs', 'NNS', 'noun, plural'),
#  ('sp', 'VBD', 'verb, past tense'),
#  ('spoils', 'VBZ', 'verb, 3rd person singular present'),
#  ('shot', 'VBD', 'verb, past tense'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('nasty', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('grin', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('gap', 'NN', 'noun, singular or mass'),
#  ('mother', 'NN', 'noun, singular or mass'),
#  ('arms', 'NNS', 'noun, plural'),
#  ('\n', '_SP', 'whitespace'),
#  ('doorbell', 'NN', 'noun, singular or mass'),
#  ('rang', 'VBD', 'verb, past tense'),
#  ('Oh', 'UH', 'interjection'),
#  ('good', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('Lord', 'NNP', 'noun, proper singular'),
#  ('said', 'VBD', 'verb, past tense'),
#  ('Aunt', 'NNP', 'noun, proper singular'),
#  ('\n', '_SP', 'whitespace'),
#  ('Petunia', 'NNP', 'noun, proper singular'),
#  ('frantically', 'RB', 'adverb'),
#  ('moment', 'NN', 'noun, singular or mass'),
#  ('later', 'RB', 'adverb'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('best', 'JJS', 'adjective, superlative'),
#  ('friend', 'NN', 'noun, singular or mass'),
#  ('Piers', 'NNPS', 'noun, proper plural'),
#  ('Polkiss', 'NNP', 'noun, proper singular'),
#  ('\n', '_SP', 'whitespace'),
#  ('walked', 'VBD', 'verb, past tense'),
#  ('mother', 'NN', 'noun, singular or mass'),
#  ('Piers', 'NNS', 'noun, plural'),
#  ('scrawny', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('boy', 'NN', 'noun, singular or mass'),
#  ('face', 'NN', 'noun, singular or mass'),
#  ('like', 'IN', 'conjunction, subordinating or preposition'),
#  ('rat', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('usually', 'RB', 'adverb'),
#  ('held', 'VBD', 'verb, past tense'),
#  ('people', 'NNS', 'noun, plural'),
#  ('arms', 'NNS', 'noun, plural'),
#  ('backs', 'NNS', 'noun, plural'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('hit', 'VBD', 'verb, past tense'),
#  ('\n', '_SP', 'whitespace'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('stopped', 'VBD', 'verb, past tense'),
#  ('pretending', 'VBG', 'verb, gerund or present participle'),
#  ('cry', 'VB', 'verb, base form'),
#  ('\n', '_SP', 'whitespace'),
#  ('Half', 'PDT', 'predeterminer'),
#  ('hour', 'NN', 'noun, singular or mass'),
#  ('later', 'RB', 'adverb'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('believe', 'VB', 'verb, base form'),
#  ('luck', 'NN', 'noun, singular or mass'),
#  ('sitting', 'VBG', 'verb, gerund or present participle'),
#  ('\n', '_SP', 'whitespace'),
#  ('Dursleys', 'NNPS', 'noun, proper plural'),
#  ('car', 'NN', 'noun, singular or mass'),
#  ('Piers', 'NNPS', 'noun, proper plural'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('way', 'NN', 'noun, singular or mass'),
#  ('zoo', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('time', 'NN', 'noun, singular or mass'),
#  ('life', 'NN', 'noun, singular or mass'),
#  ('aunt', 'NN', 'noun, singular or mass'),
#  ('uncle', 'NN', 'noun, singular or mass'),
#  ('able', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('think', 'VB', 'verb, base form'),
#  ('\n', '_SP', 'whitespace'),
#  ('left', 'VBD', 'verb, past tense'),
#  ('Uncle', 'NNP', 'noun, proper singular'),
#  ('Vernon', 'NNP', 'noun, proper singular'),
#  ('taken', 'VBN', 'verb, past participle'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('aside', 'RB', 'adverb'),
#  ('\n', '_SP', 'whitespace'),
#  ('warning', 'VBG', 'verb, gerund or present participle'),
#  ('said', 'VBN', 'verb, past participle'),
#  ('putting', 'VBG', 'verb, gerund or present participle'),
#  ('large', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('purple', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('face', 'NN', 'noun, singular or mass'),
#  ('right', 'RB', 'adverb'),
#  ('\n', '_SP', 'whitespace'),
#  ('close', 'RB', 'adverb'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('warning', 'VBG', 'verb, gerund or present participle'),
#  ('boy', 'UH', 'interjection'),
#  ('funny', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('business', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('cupboard', 'NN', 'noun, singular or mass'),
#  ('Christmas', 'NNP', 'noun, proper singular'),
#  ('\n', '_SP', 'whitespace'),
#  ('going', 'VBG', 'verb, gerund or present participle'),
#  ('said', 'VBD', 'verb, past tense'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('honestly', 'RB', 'adverb'),
#  ('\n', '_SP', 'whitespace'),
#  ('Uncle', 'NNP', 'noun, proper singular'),
#  ('Vernon', 'NNP', 'noun, proper singular'),
#  ('believe', 'VB', 'verb, base form'),
#  ('\n', '_SP', 'whitespace'),
#  ('problem', 'NN', 'noun, singular or mass'),
#  ('strange', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('things', 'NNS', 'noun, plural'),
#  ('happened', 'VBD', 'verb, past tense'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('\n', '_SP', 'whitespace'),
#  ('good', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('telling', 'VBG', 'verb, gerund or present participle'),
#  ('Dursleys', 'NNS', 'noun, plural'),
#  ('happen', 'VB', 'verb, base form'),
#  ('\n', '_SP', 'whitespace'),
#  ('Aunt', 'NNP', 'noun, proper singular'),
#  ('Petunia', 'NNP', 'noun, proper singular'),
#  ('tired', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('coming', 'VBG', 'verb, gerund or present participle'),
#  ('barbers', 'NNS', 'noun, plural'),
#  ('looking', 'VBG', 'verb, gerund or present participle'),
#  ('\n', '_SP', 'whitespace'),
#  ('taken', 'VBN', 'verb, past participle'),
#  ('pair', 'NN', 'noun, singular or mass'),
#  ('kitchen', 'NN', 'noun, singular or mass'),
#  ('scissors', 'NNS', 'noun, plural'),
#  ('cut', 'VB', 'verb, base form'),
#  ('\n', '_SP', 'whitespace'),
#  ('hair', 'NN', 'noun, singular or mass'),
#  ('short', 'RB', 'adverb'),
#  ('bald', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('bangs', 'NNS', 'noun, plural'),
#  ('left', 'VBD', 'verb, past tense'),
#  ('hide', 'VB', 'verb, base form'),
#  ('\n', '_SP', 'whitespace'),
#  ('horrible', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('scar', 'NN', 'noun, singular or mass'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('laughed', 'VBN', 'verb, past participle'),
#  ('silly', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('Harry', 'NNP', 'noun, proper singular'),
#  ('spent', 'VBD', 'verb, past tense'),
#  ('sleepless', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('\n', '_SP', 'whitespace'),
#  ('night', 'NN', 'noun, singular or mass'),
#  ('imagining', 'VBG', 'verb, gerund or present participle'),
#  ('school', 'NN', 'noun, singular or mass'),
#  ('day', 'NN', 'noun, singular or mass'),
#  ('laughed', 'VBN', 'verb, past participle'),
#  ('\n', '_SP', 'whitespace'),
#  ('baggy', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('clothes', 'NNS', 'noun, plural'),
#  ('taped', 'VBD', 'verb, past tense'),
#  ('glasses', 'NNS', 'noun, plural'),
#  ('morning', 'NN', 'noun, singular or mass'),
#  ('gotten', 'VBN', 'verb, past participle'),
#  ('\n', '_SP', 'whitespace'),
#  ('find', 'VB', 'verb, base form'),
#  ('hair', 'NN', 'noun, singular or mass'),
#  ('exactly', 'RB', 'adverb'),
#  ('Aunt', 'NNP', 'noun, proper singular'),
#  ('Petunia', 'NNP', 'noun, proper singular'),
#  ('sheared', 'VBN', 'verb, past participle'),
#  ('\n', '_SP', 'whitespace'),
#  ('given', 'VBN', 'verb, past participle'),
#  ('week', 'NN', 'noun, singular or mass'),
#  ('cupboard', 'NN', 'noun, singular or mass'),
#  ('tried', 'VBN', 'verb, past participle'),
#  ('explain', 'VB', 'verb, base form'),
#  ('\n', '_SP', 'whitespace'),
#  ('explain', 'VB', 'verb, base form'),
#  ('grown', 'VBN', 'verb, past participle'),
#  ('quickly', 'RB', 'adverb'),
#  ('\n', '_SP', 'whitespace'),
#  ('time', 'NN', 'noun, singular or mass'),
#  ('Aunt', 'NNP', 'noun, proper singular'),
#  ('Petunia', 'NNP', 'noun, proper singular'),
#  ('trying', 'VBG', 'verb, gerund or present participle'),
#  ('force', 'VB', 'verb, base form'),
#  ('revolting', 'NN', 'noun, singular or mass'),
#  ('\n', '_SP', 'whitespace'),
#  ('old', 'JJ', 'adjective (English), other noun-modifier (Chinese)'),
#  ('sweater', 'NN', 'noun, singular or mass'),
#  ('Dudley', 'NNP', 'noun, proper singular'),
#  ('brown', 'NN', 'noun, singular or mass'),
#  ('orange', 'NNP', 'noun, proper singular'),
#  ('puff', 'NNP', 'noun, proper singular'),
#  ('balls', 'NNS', 'noun, plural'),
#  ('harder', 'RBR', 'adverb, comparative'),
#  ('tried', 'VBD', 'verb, past tense'),
#  ('\n', '_SP', 'whitespace'),
#  ('pull', 'VB', 'verb, base form'),
#  ('head', 'NN', 'noun, singular or mass'),
#  ('smaller', 'JJR', 'adjective, comparative'),
#  ('finally', 'RB', 'adverb'),
#  ('\n', '_SP', 'whitespace'),
#  ('fitted', 'VBN', 'verb, past participle'),
#  ('hand', 'NN', 'noun, singular or mass'),
#  ...]
